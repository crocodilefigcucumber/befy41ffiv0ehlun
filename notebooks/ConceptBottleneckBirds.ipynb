# %% [markdown]
# # Implementing a concept bottleneck model (CBM) on the CUB dataset. Inspired by: https://arxiv.org/pdf/2007.04612

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import numpy as np

import os
import random

import pandas as pd
import requests
from tqdm import tqdm
import tarfile
from torchvision import models


from PIL import Image

import itertools

# %%
# Install gdown if you haven't already
# !pip install gdown

# Resnet 18
# !gdown 1me7X6jSSAZV0xaK_slQpxGKgF5nJTo8e
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1me7X6jSSAZV0xaK_slQpxGKgF5nJTo8e
# To: /content/resnet18-5c106cde.pth
# 100% 46.8M/46.8M [00:00<00:00, 188MB/s]

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Create a path to save your file in your Google Drive
save_dir = '/content/drive/My Drive/ConceptBottleneckBirds/'

file = 'your_filename.txt'  # Change filename as needed

# Specify the directory path you want to create

# Create directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f'Directory created at: {save_dir}')
else:
    print(f'Directory already exists at: {save_dir}')

# Example: Now you can save files in this directory
save_path = os.path.join(save_dir, file)
with open(save_path, 'w') as f:
    f.write('Hello from the birds using Colab!')
# Out:
# Mounted at /content/drive
# Directory already exists at: /content/drive/My Drive/ConceptBottleneckBirds/

# %%
def set_seed(seed):
   torch.manual_seed(seed)
   torch.cuda.manual_seed(seed)
   torch.cuda.manual_seed_all(seed)
   np.random.seed(seed)
   random.seed(seed)
   torch.backends.cudnn.deterministic = True
   torch.backends.cudnn.benchmark = False

set_seed(42)  # Replace with your seed number

# %%
class BirdsDataset(Dataset):
    def __init__(self, images, concepts, labels, transform=None):
        assert type(concepts) == type(labels) == type(images) == list, (
          "concepts, labels, and images must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(images)))
        self.images = images
        self.concepts = concepts
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        if self.transform:
            image = self.transform(image)
        concepts = self._convert_concepts_to_tensor(self.concepts[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return image, concepts, label


    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor


class CUBDataset(Dataset):
    """
    Create a PyTorch dataset from a list of image paths.

    Args:
        image_paths: List of paths to image files
        transform: Optional transform to be applied on images
                  (if None, will convert to tensor and normalize)
    """

    def __init__(self, image_paths, concepts, labels, transform=None):
      self.concepts = []
      self.labels = []
      self.images = []

      assert type(concepts) == type(labels) == type(image_paths) == list, (
        "concepts, labels, and image_paths must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(image_paths)))

      assert len(image_paths) == len(concepts) == len(labels), (
        "Number of images, concepts, and labels must match")

      base_transforms = transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            # Removed the crop from here. To allow it be applied dynamically at get time.
        ])

      # Default transform if none provided
      self.transform = transform if transform is not None else transforms.Compose([])

      for image_path, concept, label in zip(image_paths, concepts, labels):
        try:
          image = Image.open(image_path).convert('RGB')
        except Exception as e:
          print(f"Error loading image {image_path}: {str(e)}")
        # Apply base transforms
        image = base_transforms(image)

        self.images.append(image)
        self.concepts.append(self._convert_concepts_to_tensor(concept))
        self.labels.append(torch.tensor(label, dtype=torch.long))

    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Load image
        image = self.transform(self.images[idx])
        label = self.labels[idx]
        concept = self.concepts[idx]

        return image, concept, label

# %%
def download_cub200_2011():
    """
    Downloads the CUB-200-2011 dataset and extracts it.
    Returns the path to the extracted dataset.
    """
    # Create a directory for the dataset
    base_dir = '/content/CUB_200_2011'
    dataset_dir = os.path.join(base_dir, 'CUB_200_2011')

    # Check if dataset already exists
    if os.path.exists(dataset_dir) and os.path.exists(os.path.join(dataset_dir, 'images.txt')):
        print("Dataset already downloaded and extracted.")
        return dataset_dir

    os.makedirs(base_dir, exist_ok=True)

    # URL for the dataset
    url = 'https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz'
    tgz_path = os.path.join(base_dir, 'CUB_200_2011.tgz')

    # Download only if not already downloaded
    if not os.path.exists(tgz_path):
        print("Downloading CUB-200-2011 dataset...")
        response = requests.get(url, stream=True)
        total_size = int(response.headers.get('content-length', 0))

        with open(tgz_path, 'wb') as f:
            for data in tqdm(response.iter_content(chunk_size=1024),
                            total=total_size//1024,
                            unit='KB'):
                f.write(data)

    # Extract only if not already extracted
    if not os.path.exists(dataset_dir):
        print("\nExtracting dataset...")
        with tarfile.open(tgz_path, 'r:gz') as tar:
            tar.extractall(base_dir)

    # Remove the downloaded tar file to save space
    if os.path.exists(tgz_path):
        os.remove(tgz_path)

    return dataset_dir

def read_txt_file(filepath, num_cols):
    """
    Safely read space-separated text files with a specific number of columns.
    """
    data = []
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= num_cols:
                data.append(parts[:num_cols])
    return pd.DataFrame(data)

def load_cub_data(data_dir):
    """
    Loads and organizes the CUB dataset metadata.
    Returns dictionaries for image paths, labels, and attribute data.
    """
    # Load image paths and labels using the safe reader
    images_df = read_txt_file(os.path.join(data_dir, 'images.txt'), 2)
    images_df.columns = ['image_id', 'image_path']
    images_df['image_id'] = images_df['image_id'].astype(int)

    labels_df = read_txt_file(os.path.join(data_dir, 'image_class_labels.txt'), 2)
    labels_df.columns = ['image_id', 'class_id']
    labels_df['image_id'] = labels_df['image_id'].astype(int)
    labels_df['class_id'] = labels_df['class_id'].astype(int)

    # Load train/test split
    train_test_df = read_txt_file(os.path.join(data_dir, 'train_test_split.txt'), 2)
    train_test_df.columns = ['image_id', 'is_training']
    train_test_df['image_id'] = train_test_df['image_id'].astype(int)
    train_test_df['is_training'] = train_test_df['is_training'].astype(int)

    # Load attributes using the safe reader
    attr_df = read_txt_file(os.path.join(data_dir, 'attributes/image_attribute_labels.txt'), 5)
    attr_df.columns = ['image_id', 'attribute_id', 'is_present', 'certainty', 'time']
    attr_df = attr_df.astype({
        'image_id': int,
        'attribute_id': int,
        'is_present': int,
        'certainty': int,
        'time': float
    })

    print("Merging")

    # Merge dataframes
    data = images_df.merge(labels_df, on='image_id')
    data = data.merge(train_test_df, on='image_id')

    print("Creating Dictionaries")
    # Create dictionaries
    image_paths = {row['image_id']: os.path.join(data_dir, 'images', row['image_path'])
                  for _, row in data.iterrows()}

    labels = {row['image_id']: row['class_id'] - 1  # Convert to 0-based indexing
             for _, row in data.iterrows()}

    train_test = {row['image_id']: row['is_training']
                  for _, row in data.iterrows()}

    # Organize attributes
    print("Organizing Attributes")
    # This is the slow part. Optimize...
    attributes = {}
    for _, row in attr_df.iterrows():
        image_id = row['image_id']
        if image_id not in attributes:
            attributes[image_id] = []
        attributes[image_id].append({
            'attribute_id': row['attribute_id'],
            'is_present': row['is_present'],
            'certainty': row['certainty']
        })

    return {
        'image_paths': image_paths,
        'labels': labels,
        'train_test_split': train_test,
        'attributes': attributes
    }

# %%
"""
# Download and extract the dataset
data_dir = download_cub200_2011()
print(f"\nDataset directory: {data_dir}")

# Load the dataset metadata
print("\nLoading dataset metadata...")
data = load_cub_data(data_dir)

num_classes = len(set(data['labels'].values()))

first_image_id = list(data['image_paths'].keys())[0]
num_concepts = len(data['attributes'][first_image_id])

# Print some statistics
print("\nDataset statistics:")
print(f"Total number of images: {len(data['image_paths'])}")
print(f"Number of training images: {sum(data['train_test_split'].values())}")

# a map of int id to class label 0 train, 1 test
print(f"Number of test images: {len(data['train_test_split']) - sum(data['train_test_split'].values())}")
print(f"Number of classes: {num_classes}")

# Example of accessing data for first image
print(f"\nExample data for image {first_image_id}:")
print(f"Image path: {data['image_paths'][first_image_id]}")
print(f"Class label: {data['labels'][first_image_id]}")
print(f"Is training: {data['train_test_split'][first_image_id]}")
print(f"Number of concepts: {num_concepts}")

"""
# Out:
# '\n# Download and extract the dataset\ndata_dir = download_cub200_2011()\nprint(f"\nDataset directory: {data_dir}")\n\n# Load the dataset metadata\nprint("\nLoading dataset metadata...")\ndata = load_cub_data(data_dir)\n\nnum_classes = len(set(data[\'labels\'].values()))\n\nfirst_image_id = list(data[\'image_paths\'].keys())[0]\nnum_concepts = len(data[\'attributes\'][first_image_id])\n\n# Print some statistics\nprint("\nDataset statistics:")\nprint(f"Total number of images: {len(data[\'image_paths\'])}")\nprint(f"Number of training images: {sum(data[\'train_test_split\'].values())}")\n\n# a map of int id to class label 0 train, 1 test\nprint(f"Number of test images: {len(data[\'train_test_split\']) - sum(data[\'train_test_split\'].values())}")\nprint(f"Number of classes: {num_classes}")\n\n# Example of accessing data for first image\nprint(f"\nExample data for image {first_image_id}:")\nprint(f"Image path: {data[\'image_paths\'][first_image_id]}")\nprint(f"Class label: {data[\'labels\'][first_image_id]}")\nprint(f"Is training: {data[\'train_test_split\'][first_image_id]}")\nprint(f"Number of concepts: {num_concepts}")\n\n'

# %%
import copy
from torch.optim.lr_scheduler import StepLR


class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# Define the concept bottleneck model
class ConceptBottleneckModel(nn.Module):
    def __init__(self, num_concepts=10, num_classes=200):
        super(ConceptBottleneckModel, self).__init__()
        self.encoder_res = models.resnet18(weights=None)
        self.encoder_res.load_state_dict(
            torch.load("/content/resnet18-5c106cde.pth")
        )
        #n_features = self.encoder_res.fc.in_features
        self.encoder_res.fc = Identity()
        self.features = nn.Sequential(self.encoder_res)

        # Concept predictor
        self.concept_predictor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 1024), # this was (512, 256)
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_concepts),
            nn.Sigmoid()
        )


        # Class predictor
        """
        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, num_classes)
        )
        """


        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_classes)
        )

    def predict_concepts(self, x):
        features = self.features(x)
        return self.concept_predictor(features)

    def predict_classes(self, x):
      return self.class_predictor(x)

    def forward(self, x, return_concepts=False):
        features = self.features(x)
        concepts = self.concept_predictor(features)
        outputs = self.class_predictor(concepts)

        if return_concepts:
            return outputs, concepts
        return outputs


def train_concept_predictor_only(model,
                                 train_loader,
                                 val_loader,
                                 num_epochs=10,
                                 validation_interval=1,
                                 lr=0.001,
                                 restore_best_model=True,
                                 device='cuda'):
    concept_loss = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5, verbose=True)
    model = model.to(device)
    best_val_loss = np.inf
    best_state_dict = None
    epoch_since_improvement_limit = 5
    epochs_since_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        training_loss = 0.0
        train_correct = 0
        train_total = 0
        concept_total = 0
        concept_acc = 0.0


        for i, (images, concepts, _) in enumerate(train_loader):
            images = images.to(device)
            concepts = concepts.to(device)

            optimizer.zero_grad()

            # Forward pass
            predicted_concepts = model.predict_concepts(images)

            # Calculate losses
            train_loss = concept_loss(predicted_concepts, concepts)
            #print("predicted_classes = %s" % predicted_classes)
            #print("labels = %s" % labels)

            training_loss += train_loss
            train_total += concepts.shape[0]
            #_, predicted = torch.max(predicted_classes.data, 1)
            #train_correct += (predicted == labels).sum().item()
            preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
            concept_acc += (preds == concepts).float().sum()
            concept_total += concepts.size(0) * concepts.size(1)



            #print("Total Loss is: %s, Class Loss is: %s, Concept Loss: %s" % (total_loss.item(), class_loss.item(), concept_loss.item()))
            # Backward pass
            train_loss.backward()
            optimizer.step()

        # Print epoch-level metrics
        concept_acc = 100 * concept_acc / concept_total
        avg_train_loss = training_loss / len(train_loader)
        print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Training Concept Accuracy: {concept_acc:.2f}%')

        if (epoch + 1) % validation_interval == 0:
          # Validation
          model.eval()
          val_loss = np.inf
          concept_acc = 0.0
          val_total = 0
          concept_total = 0
          validation_loss = 0


          with torch.no_grad():
              for images, concepts, labels in val_loader:
                  images = images.to(device)
                  concepts = concepts.to(device)
                  labels = labels.to(device)

                  predicted_concepts = model.predict_concepts(images)
                  """
                  # 1. Check your class predictions range before CrossEntropyLoss
                  print("predicted_labels min %s max %s" %(torch.min(predicted_labels), torch.max(predicted_labels)))
                  # Should be reasonable logit values, not extreme

                  # 2. Verify label format
                  print("labels min %s max %s" % (labels.min(), labels.max()))  # Should be 0 to num_classes-1

                  # 3. Check concept predictions before BCE
                  print("predicted_concepts min %s max %s" % (torch.min(predicted_concepts), torch.max(predicted_concepts)))
                  # Should be between 0-1 after sigmoid
                  """

                  concept_total += concepts.size(0) * concepts.size(1)
                  preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
                  concept_acc += (preds == concepts).float().sum()

                  validation_loss += concept_loss(predicted_concepts, concepts)
          concept_acc = 100 * concept_acc / concept_total
          val_loss = validation_loss / len(val_loader)
          print(f'Validation Epoch {epoch+1}/{num_epochs}:')
          print(f'Validation Loss: {val_loss:.4f}')
          print(f'Validation Concept Accuracy: {concept_acc:.2f}%')


          if val_loss < best_val_loss:
            print("New Best Model Validation Loss: %s" % val_loss)
            best_val_loss = val_loss
            best_state_dict = copy.deepcopy(model.state_dict())
            torch.save(best_state_dict, 'best_model.pth')
            epochs_since_improvement = 0
          else:
            epochs_since_improvement += 1
            print(f"Epochs since last improvement: {epochs_since_improvement}")
          if epochs_since_improvement >= epoch_since_improvement_limit:
            print("Soft reset of weights and reduce learning rate triggered")
            model.load_state_dict(best_state_dict)
            scheduler.step()
            epochs_since_improvement = 0
    if restore_best_model and best_state_dict:
        model.load_state_dict(best_state_dict)


def train_class_predictor_only(model,
                train_loader,
                val_loader,
                num_epochs=10,
                validation_interval=1,
                lr=0.001,
                restore_best_model=True,
                device='cuda'):
    class_loss = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5, verbose=True)
    model = model.to(device)
    best_val_loss = np.inf
    best_state_dict = None
    epoch_since_improvement_limit = 5
    epochs_since_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        training_loss = 0.0
        train_correct = 0
        train_total = 0

        for i, (_, concepts, labels) in enumerate(train_loader):
            concepts = concepts.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # Forward pass
            predicted_classes = model.predict_classes(concepts)

            # Calculate losses
            loss = class_loss(predicted_classes, labels)
            #print("predicted_classes = %s" % predicted_classes)
            #print("labels = %s" % labels)

            training_loss += loss
            train_total += labels.shape[0]
            _, predicted = torch.max(predicted_classes.data, 1)
            train_correct += (predicted == labels).sum().item()

            #print("Total Loss is: %s, Class Loss is: %s, Concept Loss: %s" % (total_loss.item(), class_loss.item(), concept_loss.item()))
            # Backward pass
            loss.backward()
            optimizer.step()

        # Print epoch-level metrics
        avg_train_loss = training_loss / len(train_loader)
        train_acc = 100 * train_correct / train_total
        print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_acc:.2f}%')

        if (epoch + 1) % validation_interval == 0:
          # Validation
          model.eval()
          val_loss = np.inf
          val_acc = 0.0
          val_total = 0
          concept_total = 0
          validation_loss = 0


          with torch.no_grad():
              for _, concepts, labels in val_loader:
                  concepts = concepts.to(device)
                  labels = labels.to(device)

                  predicted_labels = model.predict_classes(concepts)
                  """
                  # 1. Check your class predictions range before CrossEntropyLoss
                  print("predicted_labels min %s max %s" %(torch.min(predicted_labels), torch.max(predicted_labels)))
                  # Should be reasonable logit values, not extreme

                  # 2. Verify label format
                  print("labels min %s max %s" % (labels.min(), labels.max()))  # Should be 0 to num_classes-1

                  # 3. Check concept predictions before BCE
                  print("predicted_concepts min %s max %s" % (torch.min(predicted_concepts), torch.max(predicted_concepts)))
                  # Should be between 0-1 after sigmoid
                  """

                  _, predicted = torch.max(predicted_labels.data, 1)
                  val_total += labels.size(0)
                  val_acc += (predicted == labels).sum().item()
                  validation_loss += class_loss(predicted_labels, labels)
          val_loss = validation_loss / len(val_loader)
          val_acc = 100 * val_acc / val_total
          print(f'Validation Epoch {epoch+1}/{num_epochs}:')
          print(f'Validation Loss: {val_loss:.4f}')
          print(f'Validation Class Label Accuracy: {val_acc:.2f}%')
          #scheduler.step(validation_loss)

          if val_loss < best_val_loss:
            print("New Best Model Validation Loss: %s" % val_loss)
            best_val_loss = val_loss
            best_state_dict = copy.deepcopy(model.state_dict())
            torch.save(best_state_dict, 'best_model.pth')
            epochs_since_improvement = 0
          else:
            epochs_since_improvement += 1
            print(f"Epochs since last improvement: {epochs_since_improvement}")
          if epochs_since_improvement >= epoch_since_improvement_limit:
            print("Soft reset of weights and reduce learning rate triggered")
            model.load_state_dict(best_state_dict)
            scheduler.step()
            epochs_since_improvement = 0
    if restore_best_model and best_state_dict:
        model.load_state_dict(best_state_dict)



# Training function
def train_model(model,
                train_loader,
                val_loader,
                num_epochs=10,
                validation_interval=1,
                lr=0.001,
                lambda_=1.0,
                restore_best_model=True,
                device='cuda'):
    criterion_concepts = nn.BCELoss()
    criterion_classes = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5, verbose=True)
    model = model.to(device)
    best_val_loss = np.inf
    best_state_dict = None
    epoch_since_improvement_limit = 5
    #epoch_since_improvement_limit = 5
    epochs_since_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        training_loss = 0.0
        train_correct = 0
        train_total = 0

        for i, (images, concepts, labels) in enumerate(train_loader):
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # Forward pass
            predicted_classes, predicted_concepts = model(images, return_concepts=True)

            # Calculate losses
            concept_loss = criterion_concepts(predicted_concepts, concepts)
            class_loss = criterion_classes(predicted_classes, labels)
            #print("predicted_classes = %s" % predicted_classes)
            #print("labels = %s" % labels)

            total_loss = class_loss + lambda_ * concept_loss
            training_loss += total_loss
            train_total += labels.size(0)
            _, predicted = torch.max(predicted_classes.data, 1)
            train_correct += (predicted == labels).sum().item()

            #print("Total Loss is: %s, Class Loss is: %s, Concept Loss: %s" % (total_loss.item(), class_loss.item(), concept_loss.item()))
            # Backward pass
            total_loss.backward()
            optimizer.step()

        # Print epoch-level metrics
        avg_train_loss = training_loss / len(train_loader)
        train_acc = 100 * train_correct / train_total
        print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_acc:.2f}%')

        if (epoch + 1) % validation_interval == 0:
          # Validation
          model.eval()
          val_acc = 0.0
          concept_acc = 0.0
          val_total = 0
          concept_total = 0
          validation_loss = 0


          with torch.no_grad():
              for images, concepts, labels in val_loader:
                  images = images.to(device)
                  concepts = concepts.to(device)
                  labels = labels.to(device)

                  predicted_labels, predicted_concepts = model(images, return_concepts=True)
                  """
                  # 1. Check your class predictions range before CrossEntropyLoss
                  print("predicted_labels min %s max %s" %(torch.min(predicted_labels), torch.max(predicted_labels)))
                  # Should be reasonable logit values, not extreme

                  # 2. Verify label format
                  print("labels min %s max %s" % (labels.min(), labels.max()))  # Should be 0 to num_classes-1

                  # 3. Check concept predictions before BCE
                  print("predicted_concepts min %s max %s" % (torch.min(predicted_concepts), torch.max(predicted_concepts)))
                  # Should be between 0-1 after sigmoid
                  """

                  _, predicted = torch.max(predicted_labels.data, 1)
                  val_total += labels.shape[0]
                  val_acc += (predicted == labels).sum().item()
                  concept_total += concepts.size(0) * concepts.size(1)
                  preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
                  concept_acc += (preds == concepts).float().sum()

                  concept_loss = criterion_concepts(predicted_concepts, concepts)
                  class_loss = criterion_classes(predicted_labels, labels)
                  validation_loss += class_loss + lambda_ * concept_loss
          val_acc = 100 * val_acc / val_total
          concept_acc = 100 * concept_acc / concept_total
          val_loss = validation_loss/len(val_loader)
          print(f'Validation Epoch {epoch+1}/{num_epochs}:')
          print(f'Validation Loss: {val_loss:.4f}')
          print(f'Validation Class Label Accuracy: {val_acc:.2f}%')
          print(f'Validation Concept Accuracy: {concept_acc:.2f}%')
          #scheduler.step(validation_loss)

          if val_loss < best_val_loss:
            print("New Best Model Validation Accuracy: %s" % val_acc)
            best_val_loss = val_loss
            best_state_dict = copy.deepcopy(model.state_dict())
            torch.save(best_state_dict, 'best_model.pth')
            epochs_since_improvement = 0
          else:
            epochs_since_improvement += 1
            print(f"Epochs since last improvement: {epochs_since_improvement}")
          if epochs_since_improvement >= epoch_since_improvement_limit:
            print("Soft reset of weights and reduce learning rate triggered")
            model.load_state_dict(best_state_dict)
            scheduler.step()
            epochs_since_improvement = 0
    if restore_best_model and best_state_dict:
        model.load_state_dict(best_state_dict)

# %%
def get_data_dict():
  data_dir = download_cub200_2011()
  data = load_cub_data(data_dir)
  return data


def get_train_val_test_datasets(data):

  # Initialize the split dictionary
  splits = {}

  # Get indices where value in dict is 1 (training)
  train_indices = [k for k, v in data['train_test_split'].items() if v == 1]

  # Randomly shuffle these indices
  shuffled_indices = np.random.permutation(train_indices)

  # Calculate split point for 80/20 split of training data
  n_train = int(len(train_indices) * 0.8)

  # First set all indices in original dict to 'test'
  for idx in data['train_test_split'].keys():
      splits[idx] = 'test'

  # Update training indices
  for idx in shuffled_indices[:n_train]:
      splits[idx] = 'train'

  # Update validation indices
  for idx in shuffled_indices[n_train:]:
      splits[idx] = 'val'

  data['split'] = splits


  # First get sorted IDs for train and test
  train_ids = sorted([id for id, split in data['split'].items() if split == "train"])
  val_ids = sorted([id for id, split in data['split'].items() if split == "val"])
  test_ids = sorted([id for id, split in data['split'].items() if split == "test"])

  print(len(train_ids))
  print(len(val_ids))
  print(len(test_ids))

  # Following the transformations from CBM paper
  resol = 299


  train_transforms = transforms.Compose(
    [
    transforms.RandomRotation(15),      # Rotate first while we have full image
    transforms.RandomResizedCrop(224),  # Then crop (avoiding empty corners)
    transforms.RandomHorizontalFlip(),
    ]
  )

  val_transforms = transforms.Compose([
      transforms.Resize(size=(224, 224)),
  ])

  test_transforms = transforms.Compose([
      transforms.Resize(size=(224, 224)),
      #transforms.CenterCrop(resol)
  ])


  # Create training dataset using the sorted train IDs
  train_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in train_ids],
      concepts=[data['attributes'][id] for id in train_ids],
      labels=[data['labels'][id] for id in train_ids],
      transform=train_transforms
  )

  val_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in val_ids],
      concepts=[data['attributes'][id] for id in val_ids],
      labels=[data['labels'][id] for id in val_ids],
      transform=val_transforms
  )

  # Create validation dataset using the sorted test IDs
  test_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in test_ids],
      concepts=[data['attributes'][id] for id in test_ids],
      labels=[data['labels'][id] for id in test_ids],
      transform=test_transforms
  )
   # Verify the split
  print(f"Training samples: {len(train_dataset)}")
  print(f"Validation samples: {len(val_dataset)}")
  print(f"Test samples: {len(test_dataset)}")

  return train_dataset, val_dataset, test_dataset



def get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size):

  import multiprocessing as mp

  num_cpus = mp.cpu_count()
  num_workers = num_cpus - 2
  print(f"Number of CPUs: {num_cpus}")
  print(f"Number of workers: {num_workers}")

  train_loader = DataLoader(
      train_dataset,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True
  )

  val_loader = DataLoader(
      val_dataset,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True
  )

  test_loader = DataLoader(
      test_dataset,
      batch_size=batch_size,
      shuffle=False,  # No need to shuffle validation data
      num_workers=num_workers
  )
  return train_loader, val_loader, test_loader

# %%
# %%time
data_dict = get_data_dict()
print("Creating Datasets")
train_dataset, val_dataset, test_dataset = get_train_val_test_datasets(data_dict)
print("Creating Dataloaders")
train_loader, val_loader, test_loader = get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size=512)
# Out:
# Downloading CUB-200-2011 dataset...
# 1123619KB [02:55, 6403.33KB/s]
# Extracting dataset...
# Merging
# Creating Dictionaries
# Organizing Attributes
# Creating Datasets
# 4795
# 1199
# 5794
# Training samples: 4795
# Validation samples: 1199
# Test samples: 5794
# Creating Dataloaders
# Number of CPUs: 12
# Number of workers: 10
# CPU times: user 8min 39s, sys: 25.1 s, total: 9min 4s
# Wall time: 6min 39s

# %%
# %%time
num_concepts = 312
num_classes = 200
model = ConceptBottleneckModel(num_concepts=num_concepts, num_classes=num_classes)
#model = model.to(torch.bfloat16).to('cuda')

#model = model.to(torch.bfloat16)


# lambda_ controls the balance between the class loss and the concept loss. A small lambda shrinks the importance of the concept loss.
# Out:
# CPU times: user 248 ms, sys: 120 ms, total: 367 ms
# Wall time: 311 ms
# <ipython-input-47-b5c82e94eb91>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load("/content/resnet18-5c106cde.pth")

# %%
# %%time

train_concept_predictor_only(model, train_loader, val_loader, validation_interval=3, lr=0.0001, num_epochs=150)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1, Training Loss: 0.6640, Training Concept Accuracy: 59.24%
# Epoch 2, Training Loss: 0.5306, Training Concept Accuracy: 77.78%
# Epoch 3, Training Loss: 0.4359, Training Concept Accuracy: 86.94%
# Validation Epoch 3/300:
# Validation Loss: 0.3808
# Validation Concept Accuracy: 90.55%
# New Best Model Validation Loss: tensor(0.3808, device='cuda:0')
# Epoch 4, Training Loss: 0.3712, Training Concept Accuracy: 89.93%
# Epoch 5, Training Loss: 0.3287, Training Concept Accuracy: 90.69%
# Epoch 6, Training Loss: 0.2996, Training Concept Accuracy: 90.89%
# Validation Epoch 6/300:
# Validation Loss: 0.2727
# Validation Concept Accuracy: 90.96%
# New Best Model Validation Loss: tensor(0.2727, device='cuda:0')
# Epoch 7, Training Loss: 0.2805, Training Concept Accuracy: 90.99%
# Epoch 8, Training Loss: 0.2665, Training Concept Accuracy: 91.06%
# Epoch 9, Training Loss: 0.2573, Training Concept Accuracy: 91.11%
# Validation Epoch 9/300:
# Validation Loss: 0.2471
# Validation Concept Accuracy: 91.12%
# New Best Model Validation Loss: tensor(0.2471, device='cuda:0')
# Epoch 10, Training Loss: 0.2495, Training Concept Accuracy: 91.17%
# Epoch 11, Training Loss: 0.2441, Training Concept Accuracy: 91.23%
# Epoch 12, Training Loss: 0.2384, Training Concept Accuracy: 91.30%
# Validation Epoch 12/300:
# Validation Loss: 0.2329
# Validation Concept Accuracy: 91.22%
# New Best Model Validation Loss: tensor(0.2329, device='cuda:0')
# Epoch 13, Training Loss: 0.2353, Training Concept Accuracy: 91.34%
# Epoch 14, Training Loss: 0.2321, Training Concept Accuracy: 91.40%
# Epoch 15, Training Loss: 0.2295, Training Concept Accuracy: 91.43%
# Validation Epoch 15/300:
# Validation Loss: 0.2260
# Validation Concept Accuracy: 91.34%
# New Best Model Validation Loss: tensor(0.2260, device='cuda:0')
# Epoch 16, Training Loss: 0.2267, Training Concept Accuracy: 91.47%
# Epoch 17, Training Loss: 0.2243, Training Concept Accuracy: 91.55%
# Epoch 18, Training Loss: 0.2223, Training Concept Accuracy: 91.59%
# Validation Epoch 18/300:
# Validation Loss: 0.2198
# Validation Concept Accuracy: 91.42%
# New Best Model Validation Loss: tensor(0.2198, device='cuda:0')
# Epoch 19, Training Loss: 0.2207, Training Concept Accuracy: 91.60%
# Epoch 20, Training Loss: 0.2190, Training Concept Accuracy: 91.64%
# Epoch 21, Training Loss: 0.2173, Training Concept Accuracy: 91.69%
# Validation Epoch 21/300:
# Validation Loss: 0.2168
# Validation Concept Accuracy: 91.49%
# New Best Model Validation Loss: tensor(0.2168, device='cuda:0')
# Epoch 22, Training Loss: 0.2151, Training Concept Accuracy: 91.72%
# Epoch 23, Training Loss: 0.2143, Training Concept Accuracy: 91.75%
# Epoch 24, Training Loss: 0.2133, Training Concept Accuracy: 91.81%
# Validation Epoch 24/300:
# Validation Loss: 0.2143
# Validation Concept Accuracy: 91.53%
# New Best Model Validation Loss: tensor(0.2143, device='cuda:0')
# Epoch 25, Training Loss: 0.2118, Training Concept Accuracy: 91.83%
# Epoch 26, Training Loss: 0.2098, Training Concept Accuracy: 91.87%
# Epoch 27, Training Loss: 0.2088, Training Concept Accuracy: 91.91%
# Validation Epoch 27/300:
# Validation Loss: 0.2117
# Validation Concept Accuracy: 91.57%
# New Best Model Validation Loss: tensor(0.2117, device='cuda:0')
# Epoch 28, Training Loss: 0.2081, Training Concept Accuracy: 91.97%
# Epoch 29, Training Loss: 0.2064, Training Concept Accuracy: 92.01%
# Epoch 30, Training Loss: 0.2060, Training Concept Accuracy: 92.02%
# Validation Epoch 30/300:
# Validation Loss: 0.2112
# Validation Concept Accuracy: 91.58%
# New Best Model Validation Loss: tensor(0.2112, device='cuda:0')
# Epoch 31, Training Loss: 0.2040, Training Concept Accuracy: 92.09%
# Epoch 32, Training Loss: 0.2038, Training Concept Accuracy: 92.08%
# Epoch 33, Training Loss: 0.2024, Training Concept Accuracy: 92.09%
# Validation Epoch 33/300:
# Validation Loss: 0.2098
# Validation Concept Accuracy: 91.61%
# New Best Model Validation Loss: tensor(0.2098, device='cuda:0')
# Epoch 34, Training Loss: 0.2015, Training Concept Accuracy: 92.14%
# Epoch 35, Training Loss: 0.2004, Training Concept Accuracy: 92.17%
# Epoch 36, Training Loss: 0.1995, Training Concept Accuracy: 92.22%
# Validation Epoch 36/300:
# Validation Loss: 0.2096
# Validation Concept Accuracy: 91.61%
# New Best Model Validation Loss: tensor(0.2096, device='cuda:0')
# Epoch 37, Training Loss: 0.1984, Training Concept Accuracy: 92.29%
# Epoch 38, Training Loss: 0.1975, Training Concept Accuracy: 92.32%
# Epoch 39, Training Loss: 0.1964, Training Concept Accuracy: 92.36%
# Validation Epoch 39/300:
# Validation Loss: 0.2089
# Validation Concept Accuracy: 91.61%
# New Best Model Validation Loss: tensor(0.2089, device='cuda:0')
# Epoch 40, Training Loss: 0.1954, Training Concept Accuracy: 92.37%
# Epoch 41, Training Loss: 0.1943, Training Concept Accuracy: 92.42%
# Epoch 42, Training Loss: 0.1930, Training Concept Accuracy: 92.45%
# Validation Epoch 42/300:
# Validation Loss: 0.2086
# Validation Concept Accuracy: 91.64%
# New Best Model Validation Loss: tensor(0.2086, device='cuda:0')
# Epoch 43, Training Loss: 0.1929, Training Concept Accuracy: 92.45%
# Epoch 44, Training Loss: 0.1908, Training Concept Accuracy: 92.55%
# Epoch 45, Training Loss: 0.1907, Training Concept Accuracy: 92.57%
# Validation Epoch 45/300:
# Validation Loss: 0.2100
# Validation Concept Accuracy: 91.54%
# Epochs since last improvement: 1
# Epoch 46, Training Loss: 0.1897, Training Concept Accuracy: 92.57%
# Epoch 47, Training Loss: 0.1884, Training Concept Accuracy: 92.63%
# Epoch 48, Training Loss: 0.1874, Training Concept Accuracy: 92.67%
# Validation Epoch 48/300:
# Validation Loss: 0.2086
# Validation Concept Accuracy: 91.58%
# Epochs since last improvement: 2
# Epoch 49, Training Loss: 0.1867, Training Concept Accuracy: 92.68%
# Epoch 50, Training Loss: 0.1860, Training Concept Accuracy: 92.74%
# Epoch 51, Training Loss: 0.1862, Training Concept Accuracy: 92.76%
# Validation Epoch 51/300:
# Validation Loss: 0.2106
# Validation Concept Accuracy: 91.58%
# Epochs since last improvement: 3
# Epoch 52, Training Loss: 0.1844, Training Concept Accuracy: 92.79%
# Epoch 53, Training Loss: 0.1829, Training Concept Accuracy: 92.86%
# Epoch 54, Training Loss: 0.1829, Training Concept Accuracy: 92.85%
# Validation Epoch 54/300:
# Validation Loss: 0.2103
# Validation Concept Accuracy: 91.56%
# Epochs since last improvement: 4
# Epoch 55, Training Loss: 0.1816, Training Concept Accuracy: 92.92%
# Epoch 56, Training Loss: 0.1818, Training Concept Accuracy: 92.92%
# Epoch 57, Training Loss: 0.1805, Training Concept Accuracy: 92.95%
# Validation Epoch 57/300:
# Validation Loss: 0.2107
# Validation Concept Accuracy: 91.51%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 58, Training Loss: 0.1920, Training Concept Accuracy: 92.51%
# Epoch 59, Training Loss: 0.1907, Training Concept Accuracy: 92.58%
# Epoch 60, Training Loss: 0.1910, Training Concept Accuracy: 92.56%
# Validation Epoch 60/300:
# Validation Loss: 0.2078
# Validation Concept Accuracy: 91.63%
# New Best Model Validation Loss: tensor(0.2078, device='cuda:0')
# Epoch 61, Training Loss: 0.1899, Training Concept Accuracy: 92.57%
# Epoch 62, Training Loss: 0.1884, Training Concept Accuracy: 92.67%
# Epoch 63, Training Loss: 0.1892, Training Concept Accuracy: 92.62%
# Validation Epoch 63/300:
# Validation Loss: 0.2090
# Validation Concept Accuracy: 91.58%
# Epochs since last improvement: 1
# Epoch 64, Training Loss: 0.1878, Training Concept Accuracy: 92.67%
# Epoch 65, Training Loss: 0.1873, Training Concept Accuracy: 92.66%
# Epoch 66, Training Loss: 0.1874, Training Concept Accuracy: 92.69%
# Validation Epoch 66/300:
# Validation Loss: 0.2080
# Validation Concept Accuracy: 91.62%
# Epochs since last improvement: 2
# Epoch 67, Training Loss: 0.1861, Training Concept Accuracy: 92.73%
# Epoch 68, Training Loss: 0.1857, Training Concept Accuracy: 92.74%
# Epoch 69, Training Loss: 0.1859, Training Concept Accuracy: 92.77%
# Validation Epoch 69/300:
# Validation Loss: 0.2083
# Validation Concept Accuracy: 91.63%
# Epochs since last improvement: 3
# Epoch 70, Training Loss: 0.1849, Training Concept Accuracy: 92.78%
# Epoch 71, Training Loss: 0.1847, Training Concept Accuracy: 92.81%
# Epoch 72, Training Loss: 0.1842, Training Concept Accuracy: 92.80%
# Validation Epoch 72/300:
# Validation Loss: 0.2089
# Validation Concept Accuracy: 91.61%
# Epochs since last improvement: 4
# Epoch 73, Training Loss: 0.1837, Training Concept Accuracy: 92.86%
# Epoch 74, Training Loss: 0.1824, Training Concept Accuracy: 92.88%
# Epoch 75, Training Loss: 0.1817, Training Concept Accuracy: 92.90%
# Validation Epoch 75/300:
# Validation Loss: 0.2085
# Validation Concept Accuracy: 91.58%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 76, Training Loss: 0.1900, Training Concept Accuracy: 92.59%
# Epoch 77, Training Loss: 0.1902, Training Concept Accuracy: 92.58%
# Epoch 78, Training Loss: 0.1891, Training Concept Accuracy: 92.62%
# Validation Epoch 78/300:
# Validation Loss: 0.2077
# Validation Concept Accuracy: 91.65%
# New Best Model Validation Loss: tensor(0.2077, device='cuda:0')
# Epoch 79, Training Loss: 0.1888, Training Concept Accuracy: 92.62%
# Epoch 80, Training Loss: 0.1881, Training Concept Accuracy: 92.67%
# Epoch 81, Training Loss: 0.1881, Training Concept Accuracy: 92.65%
# Validation Epoch 81/300:
# Validation Loss: 0.2072
# Validation Concept Accuracy: 91.65%
# New Best Model Validation Loss: tensor(0.2072, device='cuda:0')
# Epoch 82, Training Loss: 0.1883, Training Concept Accuracy: 92.66%
# Epoch 83, Training Loss: 0.1865, Training Concept Accuracy: 92.70%
# Epoch 84, Training Loss: 0.1867, Training Concept Accuracy: 92.70%
# Validation Epoch 84/300:
# Validation Loss: 0.2080
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 1
# Epoch 85, Training Loss: 0.1871, Training Concept Accuracy: 92.72%
# Epoch 86, Training Loss: 0.1864, Training Concept Accuracy: 92.70%
# Epoch 87, Training Loss: 0.1866, Training Concept Accuracy: 92.72%
# Validation Epoch 87/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 2
# Epoch 88, Training Loss: 0.1860, Training Concept Accuracy: 92.73%
# Epoch 89, Training Loss: 0.1857, Training Concept Accuracy: 92.77%
# Epoch 90, Training Loss: 0.1850, Training Concept Accuracy: 92.73%
# Validation Epoch 90/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 3
# Epoch 91, Training Loss: 0.1843, Training Concept Accuracy: 92.79%
# Epoch 92, Training Loss: 0.1841, Training Concept Accuracy: 92.82%
# Epoch 93, Training Loss: 0.1846, Training Concept Accuracy: 92.80%
# Validation Epoch 93/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 4
# Epoch 94, Training Loss: 0.1836, Training Concept Accuracy: 92.83%
# Epoch 95, Training Loss: 0.1842, Training Concept Accuracy: 92.83%
# Epoch 96, Training Loss: 0.1832, Training Concept Accuracy: 92.85%
# Validation Epoch 96/300:
# Validation Loss: 0.2078
# Validation Concept Accuracy: 91.63%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 97, Training Loss: 0.1872, Training Concept Accuracy: 92.67%
# Epoch 98, Training Loss: 0.1872, Training Concept Accuracy: 92.70%
# Epoch 99, Training Loss: 0.1869, Training Concept Accuracy: 92.70%
# Validation Epoch 99/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 1
# Epoch 100, Training Loss: 0.1868, Training Concept Accuracy: 92.71%
# Epoch 101, Training Loss: 0.1866, Training Concept Accuracy: 92.71%
# Epoch 102, Training Loss: 0.1863, Training Concept Accuracy: 92.71%
# Validation Epoch 102/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 2
# Epoch 103, Training Loss: 0.1866, Training Concept Accuracy: 92.69%
# Epoch 104, Training Loss: 0.1866, Training Concept Accuracy: 92.73%
# Epoch 105, Training Loss: 0.1860, Training Concept Accuracy: 92.74%
# Validation Epoch 105/300:
# Validation Loss: 0.2071
# Validation Concept Accuracy: 91.67%
# New Best Model Validation Loss: tensor(0.2071, device='cuda:0')
# Epoch 106, Training Loss: 0.1859, Training Concept Accuracy: 92.73%
# Epoch 107, Training Loss: 0.1861, Training Concept Accuracy: 92.74%
# Epoch 108, Training Loss: 0.1857, Training Concept Accuracy: 92.76%
# Validation Epoch 108/300:
# Validation Loss: 0.2074
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 1
# Epoch 109, Training Loss: 0.1855, Training Concept Accuracy: 92.74%
# Epoch 110, Training Loss: 0.1854, Training Concept Accuracy: 92.74%
# Epoch 111, Training Loss: 0.1851, Training Concept Accuracy: 92.78%
# Validation Epoch 111/300:
# Validation Loss: 0.2074
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 2
# Epoch 112, Training Loss: 0.1847, Training Concept Accuracy: 92.77%
# Epoch 113, Training Loss: 0.1844, Training Concept Accuracy: 92.79%
# Epoch 114, Training Loss: 0.1853, Training Concept Accuracy: 92.77%
# Validation Epoch 114/300:
# Validation Loss: 0.2075
# Validation Concept Accuracy: 91.62%
# Epochs since last improvement: 3
# Epoch 115, Training Loss: 0.1846, Training Concept Accuracy: 92.80%
# Epoch 116, Training Loss: 0.1849, Training Concept Accuracy: 92.77%
# Epoch 117, Training Loss: 0.1845, Training Concept Accuracy: 92.80%
# Validation Epoch 117/300:
# Validation Loss: 0.2076
# Validation Concept Accuracy: 91.63%
# Epochs since last improvement: 4
# Epoch 118, Training Loss: 0.1842, Training Concept Accuracy: 92.79%
# Epoch 119, Training Loss: 0.1849, Training Concept Accuracy: 92.76%
# Epoch 120, Training Loss: 0.1834, Training Concept Accuracy: 92.81%
# Validation Epoch 120/300:
# Validation Loss: 0.2076
# Validation Concept Accuracy: 91.63%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 121, Training Loss: 0.1857, Training Concept Accuracy: 92.78%
# Epoch 122, Training Loss: 0.1856, Training Concept Accuracy: 92.76%
# Epoch 123, Training Loss: 0.1861, Training Concept Accuracy: 92.75%
# Validation Epoch 123/300:
# Validation Loss: 0.2074
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 1
# Epoch 124, Training Loss: 0.1852, Training Concept Accuracy: 92.75%
# Epoch 125, Training Loss: 0.1849, Training Concept Accuracy: 92.77%
# Epoch 126, Training Loss: 0.1860, Training Concept Accuracy: 92.76%
# Validation Epoch 126/300:
# Validation Loss: 0.2072
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 2
# Epoch 127, Training Loss: 0.1856, Training Concept Accuracy: 92.74%
# Epoch 128, Training Loss: 0.1851, Training Concept Accuracy: 92.76%
# Epoch 129, Training Loss: 0.1860, Training Concept Accuracy: 92.73%
# Validation Epoch 129/300:
# Validation Loss: 0.2074
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 3
# Epoch 130, Training Loss: 0.1853, Training Concept Accuracy: 92.77%
# Epoch 131, Training Loss: 0.1847, Training Concept Accuracy: 92.77%
# Epoch 132, Training Loss: 0.1843, Training Concept Accuracy: 92.81%
# Validation Epoch 132/300:
# Validation Loss: 0.2073
# Validation Concept Accuracy: 91.64%
# Epochs since last improvement: 4
# Epoch 133, Training Loss: 0.1851, Training Concept Accuracy: 92.78%
# Epoch 134, Training Loss: 0.1851, Training Concept Accuracy: 92.78%
# Epoch 135, Training Loss: 0.1845, Training Concept Accuracy: 92.79%
# Validation Epoch 135/300:
# Validation Loss: 0.2074
# Validation Concept Accuracy: 91.63%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 136, Training Loss: 0.1869, Training Concept Accuracy: 92.72%
# Epoch 137, Training Loss: 0.1858, Training Concept Accuracy: 92.76%
# Epoch 138, Training Loss: 0.1855, Training Concept Accuracy: 92.75%
# Validation Epoch 138/300:
# Validation Loss: 0.2073
# Validation Concept Accuracy: 91.66%
# Epochs since last improvement: 1
# Epoch 139, Training Loss: 0.1856, Training Concept Accuracy: 92.76%
# Epoch 140, Training Loss: 0.1860, Training Concept Accuracy: 92.73%
# Epoch 141, Training Loss: 0.1855, Training Concept Accuracy: 92.74%
# Validation Epoch 141/300:
# Validation Loss: 0.2072
# Validation Concept Accuracy: 91.66%
# Epochs since last improvement: 2
# Epoch 142, Training Loss: 0.1858, Training Concept Accuracy: 92.76%
# Epoch 143, Training Loss: 0.1865, Training Concept Accuracy: 92.74%
# Epoch 144, Training Loss: 0.1855, Training Concept Accuracy: 92.76%
# Validation Epoch 144/300:
# Validation Loss: 0.2073
# Validation Concept Accuracy: 91.65%
# Epochs since last improvement: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-47-b5c82e94eb91> in train_concept_predictor_only(model, train_loader, val_loader, num_epochs, validation_interval, lr, restore_best_model, device)
#     100
#     101
# --> 102         for i, (images, concepts, _) in enumerate(train_loader):
#     103             images = images.to(device)
#     104             concepts = concepts.to(device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1446
#    1447             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448             idx, data = self._get_data()
#    1449             self._tasks_outstanding -= 1
#    1450             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1400         elif self._pin_memory:
#    1401             while self._pin_memory_thread.is_alive():
# -> 1402                 success, data = self._try_get_data()
#    1403                 if success:
#    1404                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1241         #   (bool: whether successfully get data, any: data if successful else None)
#    1242         try:
# -> 1243             data = self._data_queue.get(timeout=timeout)
#    1244             return (True, data)
#    1245         except Exception as e:
#
# /usr/lib/python3.10/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     322             else:
#     323                 if timeout > 0:
# --> 324                     gotit = waiter.acquire(True, timeout)
#     325                 else:
#     326                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# %%time

train_class_predictor_only(model, train_loader, val_loader, validation_interval=3, lr=0.0001, num_epochs=150)
# Out:
# Epoch 1, Training Loss: 2.9676, Training Accuracy: 46.65%
# Epoch 2, Training Loss: 2.8506, Training Accuracy: 48.97%
# Epoch 3, Training Loss: 2.7570, Training Accuracy: 50.30%
# Validation Epoch 3/120:
# Validation Loss: 3.1242
# Validation Class Label Accuracy: 34.86%
# New Best Model Validation Loss: tensor(3.1242, device='cuda:0')
# Epoch 4, Training Loss: 2.6589, Training Accuracy: 52.66%
# Epoch 5, Training Loss: 2.5991, Training Accuracy: 54.35%
# Epoch 6, Training Loss: 2.5142, Training Accuracy: 55.22%
# Validation Epoch 6/120:
# Validation Loss: 2.9466
# Validation Class Label Accuracy: 38.03%
# New Best Model Validation Loss: tensor(2.9466, device='cuda:0')
# Epoch 7, Training Loss: 2.4295, Training Accuracy: 56.66%
# Epoch 8, Training Loss: 2.3838, Training Accuracy: 57.33%
# Epoch 9, Training Loss: 2.3229, Training Accuracy: 58.85%
# Validation Epoch 9/120:
# Validation Loss: 2.7893
# Validation Class Label Accuracy: 39.70%
# New Best Model Validation Loss: tensor(2.7893, device='cuda:0')
# Epoch 10, Training Loss: 2.2468, Training Accuracy: 60.52%
# Epoch 11, Training Loss: 2.1970, Training Accuracy: 61.31%
# Epoch 12, Training Loss: 2.1393, Training Accuracy: 62.25%
# Validation Epoch 12/120:
# Validation Loss: 2.6628
# Validation Class Label Accuracy: 41.62%
# New Best Model Validation Loss: tensor(2.6628, device='cuda:0')
# Epoch 13, Training Loss: 2.0843, Training Accuracy: 63.27%
# Epoch 14, Training Loss: 2.0211, Training Accuracy: 64.82%
# Epoch 15, Training Loss: 1.9883, Training Accuracy: 64.53%
# Validation Epoch 15/120:
# Validation Loss: 2.5636
# Validation Class Label Accuracy: 43.29%
# New Best Model Validation Loss: tensor(2.5636, device='cuda:0')
# Epoch 16, Training Loss: 1.9356, Training Accuracy: 65.94%
# Epoch 17, Training Loss: 1.8926, Training Accuracy: 66.57%
# Epoch 18, Training Loss: 1.8355, Training Accuracy: 68.43%
# Validation Epoch 18/120:
# Validation Loss: 2.4684
# Validation Class Label Accuracy: 43.95%
# New Best Model Validation Loss: tensor(2.4684, device='cuda:0')
# Epoch 19, Training Loss: 1.7973, Training Accuracy: 68.01%
# Epoch 20, Training Loss: 1.7459, Training Accuracy: 69.38%
# Epoch 21, Training Loss: 1.7001, Training Accuracy: 70.43%
# Validation Epoch 21/120:
# Validation Loss: 2.3917
# Validation Class Label Accuracy: 44.95%
# New Best Model Validation Loss: tensor(2.3917, device='cuda:0')
# Epoch 22, Training Loss: 1.6715, Training Accuracy: 70.62%
# Epoch 23, Training Loss: 1.6406, Training Accuracy: 71.85%
# Epoch 24, Training Loss: 1.6079, Training Accuracy: 71.95%
# Validation Epoch 24/120:
# Validation Loss: 2.3229
# Validation Class Label Accuracy: 46.79%
# New Best Model Validation Loss: tensor(2.3229, device='cuda:0')
# Epoch 25, Training Loss: 1.5474, Training Accuracy: 73.14%
# Epoch 26, Training Loss: 1.5152, Training Accuracy: 73.56%
# Epoch 27, Training Loss: 1.5017, Training Accuracy: 74.33%
# Validation Epoch 27/120:
# Validation Loss: 2.2705
# Validation Class Label Accuracy: 46.29%
# New Best Model Validation Loss: tensor(2.2705, device='cuda:0')
# Epoch 28, Training Loss: 1.4502, Training Accuracy: 75.29%
# Epoch 29, Training Loss: 1.4292, Training Accuracy: 75.68%
# Epoch 30, Training Loss: 1.4076, Training Accuracy: 76.48%
# Validation Epoch 30/120:
# Validation Loss: 2.2236
# Validation Class Label Accuracy: 46.96%
# New Best Model Validation Loss: tensor(2.2236, device='cuda:0')
# Epoch 31, Training Loss: 1.3599, Training Accuracy: 76.70%
# Epoch 32, Training Loss: 1.3304, Training Accuracy: 77.94%
# Epoch 33, Training Loss: 1.3100, Training Accuracy: 77.83%
# Validation Epoch 33/120:
# Validation Loss: 2.1833
# Validation Class Label Accuracy: 48.12%
# New Best Model Validation Loss: tensor(2.1833, device='cuda:0')
# Epoch 34, Training Loss: 1.2909, Training Accuracy: 78.35%
# Epoch 35, Training Loss: 1.2600, Training Accuracy: 78.64%
# Epoch 36, Training Loss: 1.2261, Training Accuracy: 79.65%
# Validation Epoch 36/120:
# Validation Loss: 2.1411
# Validation Class Label Accuracy: 48.37%
# New Best Model Validation Loss: tensor(2.1411, device='cuda:0')
# Epoch 37, Training Loss: 1.2006, Training Accuracy: 79.79%
# Epoch 38, Training Loss: 1.1810, Training Accuracy: 80.17%
# Epoch 39, Training Loss: 1.1477, Training Accuracy: 81.77%
# Validation Epoch 39/120:
# Validation Loss: 2.1092
# Validation Class Label Accuracy: 49.04%
# New Best Model Validation Loss: tensor(2.1092, device='cuda:0')
# Epoch 40, Training Loss: 1.1098, Training Accuracy: 81.67%
# Epoch 41, Training Loss: 1.0951, Training Accuracy: 82.29%
# Epoch 42, Training Loss: 1.0692, Training Accuracy: 82.84%
# Validation Epoch 42/120:
# Validation Loss: 2.0857
# Validation Class Label Accuracy: 49.54%
# New Best Model Validation Loss: tensor(2.0857, device='cuda:0')
# Epoch 43, Training Loss: 1.0392, Training Accuracy: 83.90%
# Epoch 44, Training Loss: 1.0371, Training Accuracy: 83.07%
# Epoch 45, Training Loss: 1.0198, Training Accuracy: 83.55%
# Validation Epoch 45/120:
# Validation Loss: 2.0616
# Validation Class Label Accuracy: 49.29%
# New Best Model Validation Loss: tensor(2.0616, device='cuda:0')
# Epoch 46, Training Loss: 0.9901, Training Accuracy: 83.98%
# Epoch 47, Training Loss: 0.9655, Training Accuracy: 84.32%
# Epoch 48, Training Loss: 0.9532, Training Accuracy: 85.46%
# Validation Epoch 48/120:
# Validation Loss: 2.0410
# Validation Class Label Accuracy: 49.21%
# New Best Model Validation Loss: tensor(2.0410, device='cuda:0')
# Epoch 49, Training Loss: 0.9326, Training Accuracy: 85.63%
# Epoch 50, Training Loss: 0.9077, Training Accuracy: 85.82%
# Epoch 51, Training Loss: 0.8799, Training Accuracy: 86.72%
# Validation Epoch 51/120:
# Validation Loss: 2.0229
# Validation Class Label Accuracy: 49.29%
# New Best Model Validation Loss: tensor(2.0229, device='cuda:0')
# Epoch 52, Training Loss: 0.8843, Training Accuracy: 86.42%
# Epoch 53, Training Loss: 0.8655, Training Accuracy: 86.42%
# Epoch 54, Training Loss: 0.8458, Training Accuracy: 86.51%
# Validation Epoch 54/120:
# Validation Loss: 2.0021
# Validation Class Label Accuracy: 49.12%
# New Best Model Validation Loss: tensor(2.0021, device='cuda:0')
# Epoch 55, Training Loss: 0.8196, Training Accuracy: 87.36%
# Epoch 56, Training Loss: 0.8057, Training Accuracy: 87.76%
# Epoch 57, Training Loss: 0.7866, Training Accuracy: 88.47%
# Validation Epoch 57/120:
# Validation Loss: 1.9896
# Validation Class Label Accuracy: 48.96%
# New Best Model Validation Loss: tensor(1.9896, device='cuda:0')
# Epoch 58, Training Loss: 0.7676, Training Accuracy: 89.07%
# Epoch 59, Training Loss: 0.7530, Training Accuracy: 89.07%
# Epoch 60, Training Loss: 0.7383, Training Accuracy: 89.57%
# Validation Epoch 60/120:
# Validation Loss: 1.9778
# Validation Class Label Accuracy: 49.46%
# New Best Model Validation Loss: tensor(1.9778, device='cuda:0')
# Epoch 61, Training Loss: 0.7311, Training Accuracy: 89.74%
# Epoch 62, Training Loss: 0.7070, Training Accuracy: 90.49%
# Epoch 63, Training Loss: 0.6965, Training Accuracy: 90.11%
# Validation Epoch 63/120:
# Validation Loss: 1.9707
# Validation Class Label Accuracy: 49.46%
# New Best Model Validation Loss: tensor(1.9707, device='cuda:0')
# Epoch 64, Training Loss: 0.6815, Training Accuracy: 90.95%
# Epoch 65, Training Loss: 0.6704, Training Accuracy: 90.59%
# Epoch 66, Training Loss: 0.6564, Training Accuracy: 91.03%
# Validation Epoch 66/120:
# Validation Loss: 1.9580
# Validation Class Label Accuracy: 49.79%
# New Best Model Validation Loss: tensor(1.9580, device='cuda:0')
# Epoch 67, Training Loss: 0.6531, Training Accuracy: 90.97%
# Epoch 68, Training Loss: 0.6294, Training Accuracy: 91.68%
# Epoch 69, Training Loss: 0.6194, Training Accuracy: 91.62%
# Validation Epoch 69/120:
# Validation Loss: 1.9497
# Validation Class Label Accuracy: 49.71%
# New Best Model Validation Loss: tensor(1.9497, device='cuda:0')
# Epoch 70, Training Loss: 0.6131, Training Accuracy: 91.82%
# Epoch 71, Training Loss: 0.5963, Training Accuracy: 92.26%
# Epoch 72, Training Loss: 0.5768, Training Accuracy: 92.22%
# Validation Epoch 72/120:
# Validation Loss: 1.9420
# Validation Class Label Accuracy: 49.29%
# New Best Model Validation Loss: tensor(1.9420, device='cuda:0')
# Epoch 73, Training Loss: 0.5649, Training Accuracy: 92.87%
# Epoch 74, Training Loss: 0.5627, Training Accuracy: 92.87%
# Epoch 75, Training Loss: 0.5399, Training Accuracy: 93.39%
# Validation Epoch 75/120:
# Validation Loss: 1.9354
# Validation Class Label Accuracy: 49.54%
# New Best Model Validation Loss: tensor(1.9354, device='cuda:0')
# Epoch 76, Training Loss: 0.5390, Training Accuracy: 92.72%
# Epoch 77, Training Loss: 0.5260, Training Accuracy: 93.20%
# Epoch 78, Training Loss: 0.5204, Training Accuracy: 93.72%
# Validation Epoch 78/120:
# Validation Loss: 1.9342
# Validation Class Label Accuracy: 49.12%
# New Best Model Validation Loss: tensor(1.9342, device='cuda:0')
# Epoch 79, Training Loss: 0.4984, Training Accuracy: 93.53%
# Epoch 80, Training Loss: 0.5031, Training Accuracy: 93.41%
# Epoch 81, Training Loss: 0.4996, Training Accuracy: 94.45%
# Validation Epoch 81/120:
# Validation Loss: 1.9312
# Validation Class Label Accuracy: 49.71%
# New Best Model Validation Loss: tensor(1.9312, device='cuda:0')
# Epoch 82, Training Loss: 0.4844, Training Accuracy: 94.35%
# Epoch 83, Training Loss: 0.4713, Training Accuracy: 94.33%
# Epoch 84, Training Loss: 0.4549, Training Accuracy: 94.85%
# Validation Epoch 84/120:
# Validation Loss: 1.9266
# Validation Class Label Accuracy: 49.37%
# New Best Model Validation Loss: tensor(1.9266, device='cuda:0')
# Epoch 85, Training Loss: 0.4523, Training Accuracy: 94.68%
# Epoch 86, Training Loss: 0.4422, Training Accuracy: 95.29%
# Epoch 87, Training Loss: 0.4328, Training Accuracy: 94.91%
# Validation Epoch 87/120:
# Validation Loss: 1.9238
# Validation Class Label Accuracy: 49.21%
# New Best Model Validation Loss: tensor(1.9238, device='cuda:0')
# Epoch 88, Training Loss: 0.4417, Training Accuracy: 94.49%
# Epoch 89, Training Loss: 0.4197, Training Accuracy: 95.33%
# Epoch 90, Training Loss: 0.4080, Training Accuracy: 95.43%
# Validation Epoch 90/120:
# Validation Loss: 1.9210
# Validation Class Label Accuracy: 48.96%
# New Best Model Validation Loss: tensor(1.9210, device='cuda:0')
# Epoch 91, Training Loss: 0.4082, Training Accuracy: 95.37%
# Epoch 92, Training Loss: 0.3967, Training Accuracy: 95.37%
# Epoch 93, Training Loss: 0.3878, Training Accuracy: 95.85%
# Validation Epoch 93/120:
# Validation Loss: 1.9241
# Validation Class Label Accuracy: 49.12%
# Epochs since last improvement: 1
# Epoch 94, Training Loss: 0.3934, Training Accuracy: 95.62%
# Epoch 95, Training Loss: 0.3834, Training Accuracy: 95.64%
# Epoch 96, Training Loss: 0.3770, Training Accuracy: 96.23%
# Validation Epoch 96/120:
# Validation Loss: 1.9227
# Validation Class Label Accuracy: 49.04%
# Epochs since last improvement: 2
# Epoch 97, Training Loss: 0.3665, Training Accuracy: 96.00%
# Epoch 98, Training Loss: 0.3619, Training Accuracy: 96.50%
# Epoch 99, Training Loss: 0.3496, Training Accuracy: 96.50%
# Validation Epoch 99/120:
# Validation Loss: 1.9202
# Validation Class Label Accuracy: 49.54%
# New Best Model Validation Loss: tensor(1.9202, device='cuda:0')
# Epoch 100, Training Loss: 0.3513, Training Accuracy: 96.81%
# Epoch 101, Training Loss: 0.3441, Training Accuracy: 96.20%
# Epoch 102, Training Loss: 0.3375, Training Accuracy: 96.41%
# Validation Epoch 102/120:
# Validation Loss: 1.9220
# Validation Class Label Accuracy: 49.04%
# Epochs since last improvement: 1
# Epoch 103, Training Loss: 0.3236, Training Accuracy: 97.10%
# Epoch 104, Training Loss: 0.3265, Training Accuracy: 96.60%
# Epoch 105, Training Loss: 0.3170, Training Accuracy: 96.93%
# Validation Epoch 105/120:
# Validation Loss: 1.9191
# Validation Class Label Accuracy: 49.29%
# New Best Model Validation Loss: tensor(1.9191, device='cuda:0')
# Epoch 106, Training Loss: 0.3099, Training Accuracy: 97.16%
# Epoch 107, Training Loss: 0.3041, Training Accuracy: 97.35%
# Epoch 108, Training Loss: 0.3041, Training Accuracy: 97.00%
# Validation Epoch 108/120:
# Validation Loss: 1.9217
# Validation Class Label Accuracy: 48.79%
# Epochs since last improvement: 1
# Epoch 109, Training Loss: 0.2992, Training Accuracy: 97.02%
# Epoch 110, Training Loss: 0.2925, Training Accuracy: 97.27%
# Epoch 111, Training Loss: 0.2837, Training Accuracy: 97.39%
# Validation Epoch 111/120:
# Validation Loss: 1.9234
# Validation Class Label Accuracy: 48.79%
# Epochs since last improvement: 2
# Epoch 112, Training Loss: 0.2894, Training Accuracy: 96.79%
# Epoch 113, Training Loss: 0.2795, Training Accuracy: 97.43%
# Epoch 114, Training Loss: 0.2794, Training Accuracy: 97.12%
# Validation Epoch 114/120:
# Validation Loss: 1.9277
# Validation Class Label Accuracy: 49.12%
# Epochs since last improvement: 3
# Epoch 115, Training Loss: 0.2720, Training Accuracy: 97.56%
# Epoch 116, Training Loss: 0.2606, Training Accuracy: 97.81%
# Epoch 117, Training Loss: 0.2613, Training Accuracy: 97.73%
# Validation Epoch 117/120:
# Validation Loss: 1.9249
# Validation Class Label Accuracy: 48.79%
# Epochs since last improvement: 4
# Epoch 118, Training Loss: 0.2558, Training Accuracy: 97.52%
# Epoch 119, Training Loss: 0.2613, Training Accuracy: 97.35%
# Epoch 120, Training Loss: 0.2452, Training Accuracy: 97.94%
# Validation Epoch 120/120:
# Validation Loss: 1.9250
# Validation Class Label Accuracy: 49.21%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# CPU times: user 1min 27s, sys: 7min 35s, total: 9min 2s
# Wall time: 27min 30s

# %%
from datetime import datetime

# Create timestamp string
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')  # Format: YYYYMMDD_HHMMSS


# Evaluate model
def evaluate_model(model, test_dataloader, device='cuda'):
    model.eval()  # Set to evaluation mode
    val_acc = 0.0
    val_acc_golden = 0.0
    concept_acc = 0.0
    val_total = 0
    concept_total = 0

    with torch.no_grad():
        for images, concepts, labels in test_dataloader:
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            predicted_labels, predicted_concepts = model(images, return_concepts=True)
            golden_concept_labels = model.predict_classes(concepts)
            _, predicted = torch.max(predicted_labels.data, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()

            _, predicted_golden = torch.max(golden_concept_labels.data, 1)
            val_acc_golden += (predicted_golden == labels).sum().item()
            concept_total += concepts.size(0) * concepts.size(1)
            preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
            concept_acc += (preds == concepts).float().sum()

    val_acc = 100 * val_acc / val_total
    val_acc_golden = 100 * val_acc_golden / val_total

    concept_acc = 100 * concept_acc / concept_total
    #print(f'Validation Loss: {running_loss/len(train_loader):.4f}')
    print(f'Test Class Label Accuracy (Golden Concepts): {val_acc_golden:.2f}%')
    print(f'Test Class Label Accuracy (End to End): {val_acc:.2f}%')
    print(f'Test Concept Accuracy: {concept_acc:.2f}%')
    return val_acc, concept_acc


evaluate_model(model, test_loader)


best_state_dict = copy.deepcopy(model.state_dict())

# Save locally in this Colab
#torch.save(best_state_dict, 'cub_model.pth')

# Save to Google Drive
torch.save(best_state_dict, os.path.join(save_dir,f'cub_model_{timestamp}.pth'))
# Out:
# Test Class Label Accuracy (Golden Concepts): 50.33%
# Test Class Label Accuracy (End to End): 26.37%
# Test Concept Accuracy: 91.77%

# %%
def check_data_ranges(dataloader, name=""):
    label_min = float('inf')
    label_max = float('-inf')
    concept_mins = None  # Changed from list to None
    concept_maxs = None

    for _, concepts, labels in dataloader:
        label_min = min(label_min, labels.min().item())
        label_max = max(label_max, labels.max().item())

        if concept_mins is None:  # First iteration
            concept_mins = concepts.min(dim=0)[0]
            concept_maxs = concepts.max(dim=0)[0]
        else:
            concept_mins = torch.minimum(concept_mins, concepts.min(dim=0)[0])
            concept_maxs = torch.maximum(concept_maxs, concepts.max(dim=0)[0])

    print(f"\n{name} Dataset Stats:")
    print(f"Label range: {label_min} to {label_max}")
    print(f"Number of unique concepts: {len(concept_mins)}")

# Check both datasets
check_data_ranges(train_loader, "Train")
check_data_ranges(val_loader, "Val")
check_data_ranges(test_loader, "Test")
# Out:
# Train Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Val Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Test Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312

# %%
def check_image_stats(dataloader, name=""):
    first_batch = next(iter(dataloader))
    images, concepts, labels = first_batch

    print(f"\n{name} Dataset Image Stats:")
    print(f"Image tensor shape: {images.shape}")  # Should be [batch_size, channels, height, width]
    print(f"Image dtype: {images.dtype}")
    print(f"Value range: min={images.min():.3f}, max={images.max():.3f}")
    print(f"Mean: {images.mean():.3f}")
    print(f"Std: {images.std():.3f}")

    # Check for NaN/Inf
    print(f"Contains NaN: {torch.isnan(images).any()}")
    print(f"Contains Inf: {torch.isinf(images).any()}")

# Check both datasets
check_image_stats(train_loader, "Train")
check_image_stats(val_loader, "Val")
check_image_stats(test_loader, "Test")
# Out:
# Train Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.103
# Std: 1.056
# Contains NaN: False
# Contains Inf: False
#
# Val Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.114
# Std: 1.070
# Contains NaN: False
# Contains Inf: False
#
# Test Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.118
# Std: 1.048
# Contains NaN: False
# Contains Inf: False
