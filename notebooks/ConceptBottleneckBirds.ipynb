# %% [markdown]
# # Implementing a concept bottleneck model (CBM) on the CUB dataset. Inspired by: https://arxiv.org/pdf/2007.04612

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import numpy as np

import os
import random

import pandas as pd
import requests
from tqdm import tqdm
import tarfile
from torchvision import models


from PIL import Image

import itertools

# %%
# Install gdown if you haven't already
# !pip install gdown

# Resnet 18
# !gdown 1me7X6jSSAZV0xaK_slQpxGKgF5nJTo8e
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1me7X6jSSAZV0xaK_slQpxGKgF5nJTo8e
# To: /content/resnet18-5c106cde.pth
# 100% 46.8M/46.8M [00:00<00:00, 62.7MB/s]

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Create a path to save your file in your Google Drive
save_dir = '/content/drive/My Drive/ConceptBottleneckBirds/'

file = 'your_filename.txt'  # Change filename as needed

# Specify the directory path you want to create

# Create directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f'Directory created at: {save_dir}')
else:
    print(f'Directory already exists at: {save_dir}')

# Example: Now you can save files in this directory
save_path = os.path.join(save_dir, file)
with open(save_path, 'w') as f:
    f.write('Hello from the birds using Colab!')
# Out:
# Mounted at /content/drive
# Directory already exists at: /content/drive/My Drive/ConceptBottleneckBirds/

# %%
def set_seed(seed):
   torch.manual_seed(seed)
   torch.cuda.manual_seed(seed)
   torch.cuda.manual_seed_all(seed)
   np.random.seed(seed)
   random.seed(seed)
   torch.backends.cudnn.deterministic = True
   torch.backends.cudnn.benchmark = False

set_seed(42)  # Replace with your seed number

# %%
class BirdsDataset(Dataset):
    def __init__(self, images, concepts, labels, transform=None):
        assert type(concepts) == type(labels) == type(images) == list, (
          "concepts, labels, and images must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(images)))
        self.images = images
        self.concepts = concepts
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        if self.transform:
            image = self.transform(image)
        concepts = self._convert_concepts_to_tensor(self.concepts[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return image, concepts, label


    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor


class CUBDataset(Dataset):
    """
    Create a PyTorch dataset from a list of image paths.

    Args:
        image_paths: List of paths to image files
        transform: Optional transform to be applied on images
                  (if None, will convert to tensor and normalize)
    """

    def __init__(self, image_paths, concepts, labels, transform=None):
      self.concepts = []
      self.labels = []
      self.images = []

      assert type(concepts) == type(labels) == type(image_paths) == list, (
        "concepts, labels, and image_paths must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(image_paths)))

      assert len(image_paths) == len(concepts) == len(labels), (
        "Number of images, concepts, and labels must match")

      base_transforms = transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            # Removed the crop from here. To allow it be applied dynamically at get time.
        ])

      # Default transform if none provided
      self.transform = transform if transform is not None else transforms.Compose([])

      for image_path, concept, label in zip(image_paths, concepts, labels):
        try:
          image = Image.open(image_path).convert('RGB')
        except Exception as e:
          print(f"Error loading image {image_path}: {str(e)}")
        # Apply base transforms
        image = base_transforms(image)
        self.images.append(image)

        self.concepts.append(self._convert_concepts_to_tensor(concept))
        self.labels.append(torch.tensor(label, dtype=torch.long))

    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Load image
        image = self.transform(self.images[idx])
        label = self.labels[idx]
        concept = self.concepts[idx]

        return image, concept, label

# %%
def download_cub200_2011():
    """
    Downloads the CUB-200-2011 dataset and extracts it.
    Returns the path to the extracted dataset.
    """
    # Create a directory for the dataset
    base_dir = '/content/CUB_200_2011'
    dataset_dir = os.path.join(base_dir, 'CUB_200_2011')

    # Check if dataset already exists
    if os.path.exists(dataset_dir) and os.path.exists(os.path.join(dataset_dir, 'images.txt')):
        print("Dataset already downloaded and extracted.")
        return dataset_dir

    os.makedirs(base_dir, exist_ok=True)

    # URL for the dataset
    url = 'https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz'
    tgz_path = os.path.join(base_dir, 'CUB_200_2011.tgz')

    # Download only if not already downloaded
    if not os.path.exists(tgz_path):
        print("Downloading CUB-200-2011 dataset...")
        response = requests.get(url, stream=True)
        total_size = int(response.headers.get('content-length', 0))

        with open(tgz_path, 'wb') as f:
            for data in tqdm(response.iter_content(chunk_size=1024),
                            total=total_size//1024,
                            unit='KB'):
                f.write(data)

    # Extract only if not already extracted
    if not os.path.exists(dataset_dir):
        print("\nExtracting dataset...")
        with tarfile.open(tgz_path, 'r:gz') as tar:
            tar.extractall(base_dir)

    # Remove the downloaded tar file to save space
    if os.path.exists(tgz_path):
        os.remove(tgz_path)

    return dataset_dir

def read_txt_file(filepath, num_cols):
    """
    Safely read space-separated text files with a specific number of columns.
    """
    data = []
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= num_cols:
                data.append(parts[:num_cols])
    return pd.DataFrame(data)

def load_cub_data(data_dir):
    """
    Loads and organizes the CUB dataset metadata.
    Returns dictionaries for image paths, labels, and attribute data.
    """
    # Load image paths and labels using the safe reader
    images_df = read_txt_file(os.path.join(data_dir, 'images.txt'), 2)
    images_df.columns = ['image_id', 'image_path']
    images_df['image_id'] = images_df['image_id'].astype(int)

    labels_df = read_txt_file(os.path.join(data_dir, 'image_class_labels.txt'), 2)
    labels_df.columns = ['image_id', 'class_id']
    labels_df['image_id'] = labels_df['image_id'].astype(int)
    labels_df['class_id'] = labels_df['class_id'].astype(int)

    # Load train/test split
    train_test_df = read_txt_file(os.path.join(data_dir, 'train_test_split.txt'), 2)
    train_test_df.columns = ['image_id', 'is_training']
    train_test_df['image_id'] = train_test_df['image_id'].astype(int)
    train_test_df['is_training'] = train_test_df['is_training'].astype(int)

    # Load attributes using the safe reader
    attr_df = read_txt_file(os.path.join(data_dir, 'attributes/image_attribute_labels.txt'), 5)
    attr_df.columns = ['image_id', 'attribute_id', 'is_present', 'certainty', 'time']
    attr_df = attr_df.astype({
        'image_id': int,
        'attribute_id': int,
        'is_present': int,
        'certainty': int,
        'time': float
    })

    print("Merging")

    # Merge dataframes
    data = images_df.merge(labels_df, on='image_id')
    data = data.merge(train_test_df, on='image_id')

    print("Creating Dictionaries")
    # Create dictionaries
    image_paths = {row['image_id']: os.path.join(data_dir, 'images', row['image_path'])
                  for _, row in data.iterrows()}

    labels = {row['image_id']: row['class_id'] - 1  # Convert to 0-based indexing
             for _, row in data.iterrows()}

    train_test = {row['image_id']: row['is_training']
                  for _, row in data.iterrows()}

    # Organize attributes
    print("Organizing Attributes")
    # This is the slow part. Optimize...
    attributes = {}
    for _, row in attr_df.iterrows():
        image_id = row['image_id']
        if image_id not in attributes:
            attributes[image_id] = []
        attributes[image_id].append({
            'attribute_id': row['attribute_id'],
            'is_present': row['is_present'],
            'certainty': row['certainty']
        })

    return {
        'image_paths': image_paths,
        'labels': labels,
        'train_test_split': train_test,
        'attributes': attributes
    }

# %%
"""
# Download and extract the dataset
data_dir = download_cub200_2011()
print(f"\nDataset directory: {data_dir}")

# Load the dataset metadata
print("\nLoading dataset metadata...")
data = load_cub_data(data_dir)

num_classes = len(set(data['labels'].values()))

first_image_id = list(data['image_paths'].keys())[0]
num_concepts = len(data['attributes'][first_image_id])

# Print some statistics
print("\nDataset statistics:")
print(f"Total number of images: {len(data['image_paths'])}")
print(f"Number of training images: {sum(data['train_test_split'].values())}")

# a map of int id to class label 0 train, 1 test
print(f"Number of test images: {len(data['train_test_split']) - sum(data['train_test_split'].values())}")
print(f"Number of classes: {num_classes}")

# Example of accessing data for first image
print(f"\nExample data for image {first_image_id}:")
print(f"Image path: {data['image_paths'][first_image_id]}")
print(f"Class label: {data['labels'][first_image_id]}")
print(f"Is training: {data['train_test_split'][first_image_id]}")
print(f"Number of concepts: {num_concepts}")

"""
# Out:
# '\n# Download and extract the dataset\ndata_dir = download_cub200_2011()\nprint(f"\nDataset directory: {data_dir}")\n\n# Load the dataset metadata\nprint("\nLoading dataset metadata...")\ndata = load_cub_data(data_dir)\n\nnum_classes = len(set(data[\'labels\'].values()))\n\nfirst_image_id = list(data[\'image_paths\'].keys())[0]\nnum_concepts = len(data[\'attributes\'][first_image_id])\n\n# Print some statistics\nprint("\nDataset statistics:")\nprint(f"Total number of images: {len(data[\'image_paths\'])}")\nprint(f"Number of training images: {sum(data[\'train_test_split\'].values())}")\n\n# a map of int id to class label 0 train, 1 test\nprint(f"Number of test images: {len(data[\'train_test_split\']) - sum(data[\'train_test_split\'].values())}")\nprint(f"Number of classes: {num_classes}")\n\n# Example of accessing data for first image\nprint(f"\nExample data for image {first_image_id}:")\nprint(f"Image path: {data[\'image_paths\'][first_image_id]}")\nprint(f"Class label: {data[\'labels\'][first_image_id]}")\nprint(f"Is training: {data[\'train_test_split\'][first_image_id]}")\nprint(f"Number of concepts: {num_concepts}")\n\n'

# %%
import copy
from torch.optim.lr_scheduler import StepLR


class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# Define the concept bottleneck model
class ConceptBottleneckModel(nn.Module):
    def __init__(self, num_concepts=10, num_classes=200):
        super(ConceptBottleneckModel, self).__init__()
        self.encoder_res = models.resnet18(weights=None)
        self.encoder_res.load_state_dict(
            torch.load("/content/resnet18-5c106cde.pth")
        )
        #n_features = self.encoder_res.fc.in_features
        self.encoder_res.fc = Identity()
        self.features = nn.Sequential(self.encoder_res)

        # Concept predictor
        self.concept_predictor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 1024), # this was (512, 256)
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_concepts),
            nn.Sigmoid()
        )


        # Class predictor
        """
        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, num_classes)
        )
        """


        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_classes)
        )


    def forward(self, x, return_concepts=False):
        features = self.features(x)
        concepts = self.concept_predictor(features)
        outputs = self.class_predictor(concepts)

        if return_concepts:
            return outputs, concepts
        return outputs

# Training function
def train_model(model,
                train_loader,
                val_loader,
                num_epochs=10,
                validation_interval=1,
                lr=0.001,
                lambda_=1.0,
                restore_best_model=True,
                device='cuda'):
    criterion_concepts = nn.BCELoss()
    criterion_classes = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5, verbose=True)
    model = model.to(device)
    best_val_acc = 0.0
    best_state_dict = None
    epoch_since_improvement_limit = 5
    #epoch_since_improvement_limit = 5
    epochs_since_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        training_loss = 0.0
        train_correct = 0
        train_total = 0

        for i, (images, concepts, labels) in enumerate(train_loader):
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # Forward pass
            predicted_classes, predicted_concepts = model(images, return_concepts=True)

            # Calculate losses
            concept_loss = criterion_concepts(predicted_concepts, concepts)
            class_loss = criterion_classes(predicted_classes, labels)
            #print("predicted_classes = %s" % predicted_classes)
            #print("labels = %s" % labels)

            total_loss = class_loss + lambda_ * concept_loss
            training_loss += total_loss
            train_total += labels.size(0)
            _, predicted = torch.max(predicted_classes.data, 1)
            train_correct += (predicted == labels).sum().item()

            #print("Total Loss is: %s, Class Loss is: %s, Concept Loss: %s" % (total_loss.item(), class_loss.item(), concept_loss.item()))
            # Backward pass
            total_loss.backward()
            optimizer.step()

        # Print epoch-level metrics
        avg_train_loss = training_loss / len(train_loader)
        train_acc = 100 * train_correct / train_total
        print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_acc:.2f}%')

        if (epoch + 1) % validation_interval == 0:
          # Validation
          model.eval()
          val_acc = 0.0
          concept_acc = 0.0
          val_total = 0
          concept_total = 0
          validation_loss = 0


          with torch.no_grad():
              for images, concepts, labels in val_loader:
                  images = images.to(device)
                  concepts = concepts.to(device)
                  labels = labels.to(device)

                  predicted_labels, predicted_concepts = model(images, return_concepts=True)
                  """
                  # 1. Check your class predictions range before CrossEntropyLoss
                  print("predicted_labels min %s max %s" %(torch.min(predicted_labels), torch.max(predicted_labels)))
                  # Should be reasonable logit values, not extreme

                  # 2. Verify label format
                  print("labels min %s max %s" % (labels.min(), labels.max()))  # Should be 0 to num_classes-1

                  # 3. Check concept predictions before BCE
                  print("predicted_concepts min %s max %s" % (torch.min(predicted_concepts), torch.max(predicted_concepts)))
                  # Should be between 0-1 after sigmoid
                  """

                  _, predicted = torch.max(predicted_labels.data, 1)
                  val_total += labels.size(0)
                  val_acc += (predicted == labels).sum().item()
                  concept_total += concepts.size(0) * concepts.size(1)
                  preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
                  concept_acc += (preds == concepts).float().sum()

                  concept_loss = criterion_concepts(predicted_concepts, concepts)
                  class_loss = criterion_classes(predicted_labels, labels)
                  validation_loss += class_loss + lambda_ * concept_loss
          val_acc = 100 * val_acc / val_total
          concept_acc = 100 * concept_acc / concept_total
          print(f'Validation Epoch {epoch+1}/{num_epochs}:')
          print(f'Validation Loss: {validation_loss/len(val_loader):.4f}')
          print(f'Validation Class Label Accuracy: {val_acc:.2f}%')
          print(f'Validation Concept Accuracy: {concept_acc:.2f}%')
          #scheduler.step(validation_loss)

          if val_acc > best_val_acc:
            print("New Best Model Validation Accuracy: %s" % val_acc)
            best_val_acc = val_acc
            best_state_dict = copy.deepcopy(model.state_dict())
            torch.save(best_state_dict, 'best_model.pth')
            epochs_since_improvement = 0
          else:
            epochs_since_improvement += 1
            print(f"Epochs since last improvement: {epochs_since_improvement}")
          if epochs_since_improvement >= epoch_since_improvement_limit:
            print("Soft reset of weights and reduce learning rate triggered")
            model.load_state_dict(best_state_dict)
            scheduler.step()
            epochs_since_improvement = 0
    if restore_best_model and best_state_dict:
        model.load_state_dict(best_state_dict)

# %%
def get_data_dict():
  data_dir = download_cub200_2011()
  data = load_cub_data(data_dir)
  return data


def get_train_val_test_datasets(data):

  # Initialize the split dictionary
  splits = {}

  # Get indices where value in dict is 1 (training)
  train_indices = [k for k, v in data['train_test_split'].items() if v == 1]

  # Randomly shuffle these indices
  shuffled_indices = np.random.permutation(train_indices)

  # Calculate split point for 80/20 split of training data
  n_train = int(len(train_indices) * 0.8)

  # First set all indices in original dict to 'test'
  for idx in data['train_test_split'].keys():
      splits[idx] = 'test'

  # Update training indices
  for idx in shuffled_indices[:n_train]:
      splits[idx] = 'train'

  # Update validation indices
  for idx in shuffled_indices[n_train:]:
      splits[idx] = 'val'

  data['split'] = splits


  # First get sorted IDs for train and test
  train_ids = sorted([id for id, split in data['split'].items() if split == "train"])
  val_ids = sorted([id for id, split in data['split'].items() if split == "val"])
  test_ids = sorted([id for id, split in data['split'].items() if split == "test"])

  print(len(train_ids))
  print(len(val_ids))
  print(len(test_ids))

  # Following the transformations from CBM paper
  resol = 299


  train_transforms = transforms.Compose(
    [
    transforms.RandomRotation(15),      # Rotate first while we have full image
    transforms.RandomResizedCrop(224),  # Then crop (avoiding empty corners)
    transforms.RandomHorizontalFlip(),
    ]
  )

  val_transforms = transforms.Compose([
      transforms.Resize(size=(224, 224)),
  ])

  test_transforms = transforms.Compose([
      transforms.Resize(size=(224, 224)),
      #transforms.CenterCrop(resol)
  ])


  # Create training dataset using the sorted train IDs
  train_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in train_ids],
      concepts=[data['attributes'][id] for id in train_ids],
      labels=[data['labels'][id] for id in train_ids],
      transform=train_transforms
  )

  val_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in val_ids],
      concepts=[data['attributes'][id] for id in val_ids],
      labels=[data['labels'][id] for id in val_ids],
      transform=val_transforms
  )

  # Create validation dataset using the sorted test IDs
  test_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in test_ids],
      concepts=[data['attributes'][id] for id in test_ids],
      labels=[data['labels'][id] for id in test_ids],
      transform=test_transforms
  )
   # Verify the split
  print(f"Training samples: {len(train_dataset)}")
  print(f"Validation samples: {len(val_dataset)}")
  print(f"Test samples: {len(test_dataset)}")

  return train_dataset, val_dataset, test_dataset



def get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size):

  import multiprocessing as mp

  num_cpus = mp.cpu_count()
  num_workers = num_cpus - 2
  print(f"Number of CPUs: {num_cpus}")
  print(f"Number of workers: {num_workers}")

  train_loader = DataLoader(
      train_dataset,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True
  )

  val_loader = DataLoader(
      val_dataset,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True
  )

  test_loader = DataLoader(
      test_dataset,
      batch_size=batch_size,
      shuffle=False,  # No need to shuffle validation data
      num_workers=num_workers
  )
  return train_loader, val_loader, test_loader

# %%
# %%time
data_dict = get_data_dict()
print("Creating Datasets")
train_dataset, val_dataset, test_dataset = get_train_val_test_datasets(data_dict)
print("Creating Dataloaders")
train_loader, val_loader, test_loader = get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size=512)
# Out:
# Downloading CUB-200-2011 dataset...
# 1123619KB [00:43, 26014.92KB/s]
# Extracting dataset...
# Merging
# Creating Dictionaries
# Organizing Attributes
# Creating Datasets
# 4795
# 1199
# 5794
# Training samples: 4795
# Validation samples: 1199
# Test samples: 5794
# Creating Dataloaders
# Number of CPUs: 12
# Number of workers: 10
# CPU times: user 8min 28s, sys: 23.7 s, total: 8min 52s
# Wall time: 4min 24s

# %%
# %%time
num_concepts = 312
num_classes = 200
model = ConceptBottleneckModel(num_concepts=num_concepts, num_classes=num_classes)
#model = model.to(torch.bfloat16).to('cuda')

#model = model.to(torch.bfloat16)


# lambda_ controls the balance between the class loss and the concept loss. A small lambda shrinks the importance of the concept loss.
# Out:
# CPU times: user 257 ms, sys: 87.9 ms, total: 345 ms
# Wall time: 291 ms
# <ipython-input-26-109e98e6798d>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load("/content/resnet18-5c106cde.pth")

# %%
# %%time

train_model(model, train_loader, val_loader, validation_interval=3, lr=0.0001, lambda_=1, num_epochs=300)
# Out:
# Epoch 1, Training Loss: 6.1614, Training Accuracy: 0.56%
# Epoch 2, Training Loss: 6.0415, Training Accuracy: 0.83%
# Epoch 3, Training Loss: 5.9136, Training Accuracy: 1.15%
# Validation Epoch 3/300:
# Validation Loss: 5.8607
# Validation Class Label Accuracy: 2.00%
# Validation Concept Accuracy: 66.62%
# New Best Model Validation Accuracy: 2.0016680567139282
# Epoch 4, Training Loss: 5.7862, Training Accuracy: 2.25%
# Epoch 5, Training Loss: 5.6312, Training Accuracy: 3.77%
# Epoch 6, Training Loss: 5.4873, Training Accuracy: 4.38%
# Validation Epoch 6/300:
# Validation Loss: 5.2679
# Validation Class Label Accuracy: 11.51%
# Validation Concept Accuracy: 75.88%
# New Best Model Validation Accuracy: 11.509591326105088
# Epoch 7, Training Loss: 5.3004, Training Accuracy: 6.65%
# Epoch 8, Training Loss: 5.1425, Training Accuracy: 7.13%
# Epoch 9, Training Loss: 4.9895, Training Accuracy: 8.74%
# Validation Epoch 9/300:
# Validation Loss: 4.6998
# Validation Class Label Accuracy: 17.01%
# Validation Concept Accuracy: 80.67%
# New Best Model Validation Accuracy: 17.01417848206839
# Epoch 10, Training Loss: 4.8251, Training Accuracy: 11.12%
# Epoch 11, Training Loss: 4.6742, Training Accuracy: 12.87%
# Epoch 12, Training Loss: 4.5314, Training Accuracy: 14.64%
# Validation Epoch 12/300:
# Validation Loss: 4.2872
# Validation Class Label Accuracy: 20.52%
# Validation Concept Accuracy: 83.60%
# New Best Model Validation Accuracy: 20.517097581317763
# Epoch 13, Training Loss: 4.3998, Training Accuracy: 16.77%
# Epoch 14, Training Loss: 4.2491, Training Accuracy: 18.69%
# Epoch 15, Training Loss: 4.1356, Training Accuracy: 19.71%
# Validation Epoch 15/300:
# Validation Loss: 3.8659
# Validation Class Label Accuracy: 26.02%
# Validation Concept Accuracy: 85.60%
# New Best Model Validation Accuracy: 26.021684737281067
# Epoch 16, Training Loss: 4.0250, Training Accuracy: 22.52%
# Epoch 17, Training Loss: 3.8764, Training Accuracy: 25.09%
# Epoch 18, Training Loss: 3.7850, Training Accuracy: 26.65%
# Validation Epoch 18/300:
# Validation Loss: 3.5257
# Validation Class Label Accuracy: 33.28%
# Validation Concept Accuracy: 86.83%
# New Best Model Validation Accuracy: 33.277731442869054
# Epoch 19, Training Loss: 3.6689, Training Accuracy: 29.09%
# Epoch 20, Training Loss: 3.5609, Training Accuracy: 30.51%
# Epoch 21, Training Loss: 3.4710, Training Accuracy: 32.58%
# Validation Epoch 21/300:
# Validation Loss: 3.1923
# Validation Class Label Accuracy: 38.37%
# Validation Concept Accuracy: 87.77%
# New Best Model Validation Accuracy: 38.36530442035029
# Epoch 22, Training Loss: 3.3530, Training Accuracy: 34.70%
# Epoch 23, Training Loss: 3.2557, Training Accuracy: 36.37%
# Epoch 24, Training Loss: 3.1608, Training Accuracy: 38.54%
# Validation Epoch 24/300:
# Validation Loss: 2.9066
# Validation Class Label Accuracy: 44.37%
# Validation Concept Accuracy: 88.33%
# New Best Model Validation Accuracy: 44.37030859049208
# Epoch 25, Training Loss: 3.0939, Training Accuracy: 40.04%
# Epoch 26, Training Loss: 3.0009, Training Accuracy: 41.77%
# Epoch 27, Training Loss: 2.9052, Training Accuracy: 44.21%
# Validation Epoch 27/300:
# Validation Loss: 2.6389
# Validation Class Label Accuracy: 47.46%
# Validation Concept Accuracy: 88.68%
# New Best Model Validation Accuracy: 47.456213511259385
# Epoch 28, Training Loss: 2.8326, Training Accuracy: 44.65%
# Epoch 29, Training Loss: 2.7766, Training Accuracy: 45.90%
# Epoch 30, Training Loss: 2.6760, Training Accuracy: 49.47%
# Validation Epoch 30/300:
# Validation Loss: 2.4666
# Validation Class Label Accuracy: 51.46%
# Validation Concept Accuracy: 89.06%
# New Best Model Validation Accuracy: 51.45954962468724
# Epoch 31, Training Loss: 2.6202, Training Accuracy: 48.63%
# Epoch 32, Training Loss: 2.5668, Training Accuracy: 50.14%
# Epoch 33, Training Loss: 2.5109, Training Accuracy: 51.70%
# Validation Epoch 33/300:
# Validation Loss: 2.2789
# Validation Class Label Accuracy: 54.30%
# Validation Concept Accuracy: 89.15%
# New Best Model Validation Accuracy: 54.295246038365306
# Epoch 34, Training Loss: 2.4435, Training Accuracy: 52.51%
# Epoch 35, Training Loss: 2.4052, Training Accuracy: 53.91%
# Epoch 36, Training Loss: 2.3154, Training Accuracy: 55.16%
# Validation Epoch 36/300:
# Validation Loss: 2.1292
# Validation Class Label Accuracy: 58.05%
# Validation Concept Accuracy: 89.40%
# New Best Model Validation Accuracy: 58.04837364470392
# Epoch 37, Training Loss: 2.2540, Training Accuracy: 57.04%
# Epoch 38, Training Loss: 2.2300, Training Accuracy: 56.70%
# Epoch 39, Training Loss: 2.1581, Training Accuracy: 60.54%
# Validation Epoch 39/300:
# Validation Loss: 2.0106
# Validation Class Label Accuracy: 59.38%
# Validation Concept Accuracy: 89.46%
# New Best Model Validation Accuracy: 59.382819015846536
# Epoch 40, Training Loss: 2.1320, Training Accuracy: 59.92%
# Epoch 41, Training Loss: 2.0902, Training Accuracy: 60.33%
# Epoch 42, Training Loss: 2.0249, Training Accuracy: 62.42%
# Validation Epoch 42/300:
# Validation Loss: 1.9129
# Validation Class Label Accuracy: 61.88%
# Validation Concept Accuracy: 89.60%
# New Best Model Validation Accuracy: 61.88490408673895
# Epoch 43, Training Loss: 2.0393, Training Accuracy: 61.63%
# Epoch 44, Training Loss: 1.9556, Training Accuracy: 63.25%
# Epoch 45, Training Loss: 1.9524, Training Accuracy: 64.36%
# Validation Epoch 45/300:
# Validation Loss: 1.8371
# Validation Class Label Accuracy: 62.30%
# Validation Concept Accuracy: 89.67%
# New Best Model Validation Accuracy: 62.30191826522102
# Epoch 46, Training Loss: 1.8659, Training Accuracy: 65.94%
# Epoch 47, Training Loss: 1.8460, Training Accuracy: 66.92%
# Epoch 48, Training Loss: 1.8186, Training Accuracy: 66.86%
# Validation Epoch 48/300:
# Validation Loss: 1.7516
# Validation Class Label Accuracy: 63.89%
# Validation Concept Accuracy: 89.74%
# New Best Model Validation Accuracy: 63.88657214345288
# Epoch 49, Training Loss: 1.7905, Training Accuracy: 67.70%
# Epoch 50, Training Loss: 1.7335, Training Accuracy: 68.72%
# Epoch 51, Training Loss: 1.7246, Training Accuracy: 68.59%
# Validation Epoch 51/300:
# Validation Loss: 1.7174
# Validation Class Label Accuracy: 63.39%
# Validation Concept Accuracy: 89.77%
# Epochs since last improvement: 1
# Epoch 52, Training Loss: 1.7031, Training Accuracy: 69.03%
# Epoch 53, Training Loss: 1.6216, Training Accuracy: 71.28%
# Epoch 54, Training Loss: 1.6077, Training Accuracy: 71.12%
# Validation Epoch 54/300:
# Validation Loss: 1.6655
# Validation Class Label Accuracy: 64.97%
# Validation Concept Accuracy: 89.80%
# New Best Model Validation Accuracy: 64.97080900750626
# Epoch 55, Training Loss: 1.5827, Training Accuracy: 72.51%
# Epoch 56, Training Loss: 1.5493, Training Accuracy: 72.49%
# Epoch 57, Training Loss: 1.5154, Training Accuracy: 72.85%
# Validation Epoch 57/300:
# Validation Loss: 1.6057
# Validation Class Label Accuracy: 64.64%
# Validation Concept Accuracy: 89.87%
# Epochs since last improvement: 1
# Epoch 58, Training Loss: 1.5056, Training Accuracy: 74.08%
# Epoch 59, Training Loss: 1.4902, Training Accuracy: 73.85%
# Epoch 60, Training Loss: 1.4647, Training Accuracy: 74.37%
# Validation Epoch 60/300:
# Validation Loss: 1.5869
# Validation Class Label Accuracy: 65.55%
# Validation Concept Accuracy: 89.91%
# New Best Model Validation Accuracy: 65.55462885738115
# Epoch 61, Training Loss: 1.4397, Training Accuracy: 75.08%
# Epoch 62, Training Loss: 1.4361, Training Accuracy: 75.25%
# Epoch 63, Training Loss: 1.4175, Training Accuracy: 76.04%
# Validation Epoch 63/300:
# Validation Loss: 1.5434
# Validation Class Label Accuracy: 65.22%
# Validation Concept Accuracy: 89.93%
# Epochs since last improvement: 1
# Epoch 64, Training Loss: 1.3896, Training Accuracy: 75.70%
# Epoch 65, Training Loss: 1.4161, Training Accuracy: 76.18%
# Epoch 66, Training Loss: 1.3166, Training Accuracy: 78.25%
# Validation Epoch 66/300:
# Validation Loss: 1.5182
# Validation Class Label Accuracy: 67.22%
# Validation Concept Accuracy: 89.92%
# New Best Model Validation Accuracy: 67.22268557130943
# Epoch 67, Training Loss: 1.3313, Training Accuracy: 78.31%
# Epoch 68, Training Loss: 1.2926, Training Accuracy: 77.73%
# Epoch 69, Training Loss: 1.2832, Training Accuracy: 79.62%
# Validation Epoch 69/300:
# Validation Loss: 1.4972
# Validation Class Label Accuracy: 67.14%
# Validation Concept Accuracy: 89.94%
# Epochs since last improvement: 1
# Epoch 70, Training Loss: 1.2592, Training Accuracy: 79.25%
# Epoch 71, Training Loss: 1.2261, Training Accuracy: 80.50%
# Epoch 72, Training Loss: 1.2481, Training Accuracy: 79.52%
# Validation Epoch 72/300:
# Validation Loss: 1.4754
# Validation Class Label Accuracy: 67.81%
# Validation Concept Accuracy: 89.93%
# New Best Model Validation Accuracy: 67.80650542118433
# Epoch 73, Training Loss: 1.2097, Training Accuracy: 79.77%
# Epoch 74, Training Loss: 1.2110, Training Accuracy: 80.56%
# Epoch 75, Training Loss: 1.2157, Training Accuracy: 80.29%
# Validation Epoch 75/300:
# Validation Loss: 1.4679
# Validation Class Label Accuracy: 66.39%
# Validation Concept Accuracy: 89.96%
# Epochs since last improvement: 1
# Epoch 76, Training Loss: 1.1820, Training Accuracy: 81.31%
# Epoch 77, Training Loss: 1.1859, Training Accuracy: 80.02%
# Epoch 78, Training Loss: 1.1829, Training Accuracy: 81.56%
# Validation Epoch 78/300:
# Validation Loss: 1.4674
# Validation Class Label Accuracy: 66.97%
# Validation Concept Accuracy: 89.99%
# Epochs since last improvement: 2
# Epoch 79, Training Loss: 1.1481, Training Accuracy: 82.52%
# Epoch 80, Training Loss: 1.1016, Training Accuracy: 82.54%
# Epoch 81, Training Loss: 1.1271, Training Accuracy: 82.67%
# Validation Epoch 81/300:
# Validation Loss: 1.4766
# Validation Class Label Accuracy: 67.39%
# Validation Concept Accuracy: 90.01%
# Epochs since last improvement: 3
# Epoch 82, Training Loss: 1.0830, Training Accuracy: 83.07%
# Epoch 83, Training Loss: 1.0905, Training Accuracy: 83.21%
# Epoch 84, Training Loss: 1.0579, Training Accuracy: 83.50%
# Validation Epoch 84/300:
# Validation Loss: 1.4890
# Validation Class Label Accuracy: 65.97%
# Validation Concept Accuracy: 90.03%
# Epochs since last improvement: 4
# Epoch 85, Training Loss: 1.0488, Training Accuracy: 84.32%
# Epoch 86, Training Loss: 0.9985, Training Accuracy: 85.59%
# Epoch 87, Training Loss: 1.0478, Training Accuracy: 83.82%
# Validation Epoch 87/300:
# Validation Loss: 1.4342
# Validation Class Label Accuracy: 66.81%
# Validation Concept Accuracy: 90.03%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 88, Training Loss: 1.2337, Training Accuracy: 80.00%
# Epoch 89, Training Loss: 1.1836, Training Accuracy: 81.21%
# Epoch 90, Training Loss: 1.1931, Training Accuracy: 80.83%
# Validation Epoch 90/300:
# Validation Loss: 1.4551
# Validation Class Label Accuracy: 67.31%
# Validation Concept Accuracy: 89.97%
# Epochs since last improvement: 1
# Epoch 91, Training Loss: 1.1952, Training Accuracy: 81.61%
# Epoch 92, Training Loss: 1.1624, Training Accuracy: 80.94%
# Epoch 93, Training Loss: 1.1904, Training Accuracy: 80.73%
# Validation Epoch 93/300:
# Validation Loss: 1.4314
# Validation Class Label Accuracy: 67.56%
# Validation Concept Accuracy: 89.99%
# Epochs since last improvement: 2
# Epoch 94, Training Loss: 1.1799, Training Accuracy: 81.42%
# Epoch 95, Training Loss: 1.1479, Training Accuracy: 82.54%
# Epoch 96, Training Loss: 1.1220, Training Accuracy: 81.71%
# Validation Epoch 96/300:
# Validation Loss: 1.4128
# Validation Class Label Accuracy: 67.56%
# Validation Concept Accuracy: 90.01%
# Epochs since last improvement: 3
# Epoch 97, Training Loss: 1.1062, Training Accuracy: 82.75%
# Epoch 98, Training Loss: 1.1146, Training Accuracy: 82.34%
# Epoch 99, Training Loss: 1.0884, Training Accuracy: 83.52%
# Validation Epoch 99/300:
# Validation Loss: 1.4108
# Validation Class Label Accuracy: 68.31%
# Validation Concept Accuracy: 90.00%
# New Best Model Validation Accuracy: 68.30692243536281
# Epoch 100, Training Loss: 1.0780, Training Accuracy: 83.65%
# Epoch 101, Training Loss: 1.0960, Training Accuracy: 83.67%
# Epoch 102, Training Loss: 1.0567, Training Accuracy: 84.61%
# Validation Epoch 102/300:
# Validation Loss: 1.4242
# Validation Class Label Accuracy: 67.47%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 1
# Epoch 103, Training Loss: 1.0542, Training Accuracy: 83.94%
# Epoch 104, Training Loss: 1.0861, Training Accuracy: 83.40%
# Epoch 105, Training Loss: 1.0310, Training Accuracy: 84.98%
# Validation Epoch 105/300:
# Validation Loss: 1.4104
# Validation Class Label Accuracy: 67.56%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 2
# Epoch 106, Training Loss: 1.0862, Training Accuracy: 83.25%
# Epoch 107, Training Loss: 1.0632, Training Accuracy: 83.75%
# Epoch 108, Training Loss: 1.0232, Training Accuracy: 85.44%
# Validation Epoch 108/300:
# Validation Loss: 1.4174
# Validation Class Label Accuracy: 67.14%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 3
# Epoch 109, Training Loss: 1.0263, Training Accuracy: 84.67%
# Epoch 110, Training Loss: 1.0521, Training Accuracy: 83.77%
# Epoch 111, Training Loss: 1.0230, Training Accuracy: 84.34%
# Validation Epoch 111/300:
# Validation Loss: 1.3900
# Validation Class Label Accuracy: 67.81%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 4
# Epoch 112, Training Loss: 1.0097, Training Accuracy: 85.42%
# Epoch 113, Training Loss: 1.0140, Training Accuracy: 84.98%
# Epoch 114, Training Loss: 1.0240, Training Accuracy: 84.44%
# Validation Epoch 114/300:
# Validation Loss: 1.4168
# Validation Class Label Accuracy: 67.89%
# Validation Concept Accuracy: 90.07%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 115, Training Loss: 1.1010, Training Accuracy: 82.90%
# Epoch 116, Training Loss: 1.0979, Training Accuracy: 82.61%
# Epoch 117, Training Loss: 1.0534, Training Accuracy: 84.00%
# Validation Epoch 117/300:
# Validation Loss: 1.3961
# Validation Class Label Accuracy: 68.72%
# Validation Concept Accuracy: 90.02%
# New Best Model Validation Accuracy: 68.72393661384487
# Epoch 118, Training Loss: 1.0884, Training Accuracy: 83.09%
# Epoch 119, Training Loss: 1.0681, Training Accuracy: 83.75%
# Epoch 120, Training Loss: 1.0752, Training Accuracy: 83.07%
# Validation Epoch 120/300:
# Validation Loss: 1.3915
# Validation Class Label Accuracy: 68.14%
# Validation Concept Accuracy: 90.01%
# Epochs since last improvement: 1
# Epoch 121, Training Loss: 1.0725, Training Accuracy: 83.86%
# Epoch 122, Training Loss: 1.0610, Training Accuracy: 84.40%
# Epoch 123, Training Loss: 1.0694, Training Accuracy: 83.52%
# Validation Epoch 123/300:
# Validation Loss: 1.3876
# Validation Class Label Accuracy: 68.14%
# Validation Concept Accuracy: 90.02%
# Epochs since last improvement: 2
# Epoch 124, Training Loss: 1.0693, Training Accuracy: 83.61%
# Epoch 125, Training Loss: 1.0237, Training Accuracy: 84.19%
# Epoch 126, Training Loss: 1.0352, Training Accuracy: 83.55%
# Validation Epoch 126/300:
# Validation Loss: 1.3846
# Validation Class Label Accuracy: 68.22%
# Validation Concept Accuracy: 90.02%
# Epochs since last improvement: 3
# Epoch 127, Training Loss: 1.0658, Training Accuracy: 84.36%
# Epoch 128, Training Loss: 1.0490, Training Accuracy: 84.50%
# Epoch 129, Training Loss: 1.0518, Training Accuracy: 83.77%
# Validation Epoch 129/300:
# Validation Loss: 1.3759
# Validation Class Label Accuracy: 68.47%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 4
# Epoch 130, Training Loss: 1.0329, Training Accuracy: 85.13%
# Epoch 131, Training Loss: 1.0091, Training Accuracy: 85.34%
# Epoch 132, Training Loss: 1.0336, Training Accuracy: 84.94%
# Validation Epoch 132/300:
# Validation Loss: 1.3807
# Validation Class Label Accuracy: 68.39%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 133, Training Loss: 1.0458, Training Accuracy: 84.59%
# Epoch 134, Training Loss: 1.0664, Training Accuracy: 83.73%
# Epoch 135, Training Loss: 1.0632, Training Accuracy: 83.48%
# Validation Epoch 135/300:
# Validation Loss: 1.3936
# Validation Class Label Accuracy: 68.81%
# Validation Concept Accuracy: 90.02%
# New Best Model Validation Accuracy: 68.80733944954129
# Epoch 136, Training Loss: 1.0493, Training Accuracy: 84.11%
# Epoch 137, Training Loss: 1.0705, Training Accuracy: 83.88%
# Epoch 138, Training Loss: 1.0269, Training Accuracy: 84.65%
# Validation Epoch 138/300:
# Validation Loss: 1.3872
# Validation Class Label Accuracy: 68.89%
# Validation Concept Accuracy: 90.02%
# New Best Model Validation Accuracy: 68.89074228523769
# Epoch 139, Training Loss: 1.0435, Training Accuracy: 84.98%
# Epoch 140, Training Loss: 1.0607, Training Accuracy: 83.90%
# Epoch 141, Training Loss: 1.0447, Training Accuracy: 84.57%
# Validation Epoch 141/300:
# Validation Loss: 1.3859
# Validation Class Label Accuracy: 68.56%
# Validation Concept Accuracy: 90.03%
# Epochs since last improvement: 1
# Epoch 142, Training Loss: 1.0287, Training Accuracy: 84.71%
# Epoch 143, Training Loss: 1.0295, Training Accuracy: 84.23%
# Epoch 144, Training Loss: 1.0424, Training Accuracy: 84.80%
# Validation Epoch 144/300:
# Validation Loss: 1.3890
# Validation Class Label Accuracy: 68.64%
# Validation Concept Accuracy: 90.03%
# Epochs since last improvement: 2
# Epoch 145, Training Loss: 1.0458, Training Accuracy: 84.57%
# Epoch 146, Training Loss: 1.0496, Training Accuracy: 84.50%
# Epoch 147, Training Loss: 1.0302, Training Accuracy: 84.86%
# Validation Epoch 147/300:
# Validation Loss: 1.3965
# Validation Class Label Accuracy: 68.56%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 3
# Epoch 148, Training Loss: 1.0450, Training Accuracy: 84.30%
# Epoch 149, Training Loss: 1.0527, Training Accuracy: 83.94%
# Epoch 150, Training Loss: 1.0390, Training Accuracy: 84.53%
# Validation Epoch 150/300:
# Validation Loss: 1.3826
# Validation Class Label Accuracy: 69.31%
# Validation Concept Accuracy: 90.03%
# New Best Model Validation Accuracy: 69.30775646371977
# Epoch 151, Training Loss: 1.0612, Training Accuracy: 84.21%
# Epoch 152, Training Loss: 1.0464, Training Accuracy: 84.21%
# Epoch 153, Training Loss: 1.0077, Training Accuracy: 85.57%
# Validation Epoch 153/300:
# Validation Loss: 1.3868
# Validation Class Label Accuracy: 68.64%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 1
# Epoch 154, Training Loss: 1.0296, Training Accuracy: 84.38%
# Epoch 155, Training Loss: 1.0119, Training Accuracy: 85.26%
# Epoch 156, Training Loss: 1.0044, Training Accuracy: 85.86%
# Validation Epoch 156/300:
# Validation Loss: 1.3861
# Validation Class Label Accuracy: 68.81%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 2
# Epoch 157, Training Loss: 1.0518, Training Accuracy: 84.53%
# Epoch 158, Training Loss: 1.0309, Training Accuracy: 85.17%
# Epoch 159, Training Loss: 1.0114, Training Accuracy: 85.01%
# Validation Epoch 159/300:
# Validation Loss: 1.3793
# Validation Class Label Accuracy: 69.31%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 3
# Epoch 160, Training Loss: 1.0434, Training Accuracy: 84.42%
# Epoch 161, Training Loss: 0.9696, Training Accuracy: 86.26%
# Epoch 162, Training Loss: 0.9937, Training Accuracy: 85.61%
# Validation Epoch 162/300:
# Validation Loss: 1.3823
# Validation Class Label Accuracy: 69.31%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 4
# Epoch 163, Training Loss: 0.9972, Training Accuracy: 85.44%
# Epoch 164, Training Loss: 0.9996, Training Accuracy: 85.34%
# Epoch 165, Training Loss: 1.0257, Training Accuracy: 84.48%
# Validation Epoch 165/300:
# Validation Loss: 1.3771
# Validation Class Label Accuracy: 69.89%
# Validation Concept Accuracy: 90.04%
# New Best Model Validation Accuracy: 69.89157631359467
# Epoch 166, Training Loss: 0.9987, Training Accuracy: 85.55%
# Epoch 167, Training Loss: 1.0059, Training Accuracy: 85.21%
# Epoch 168, Training Loss: 0.9914, Training Accuracy: 85.57%
# Validation Epoch 168/300:
# Validation Loss: 1.3696
# Validation Class Label Accuracy: 69.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 169, Training Loss: 1.0034, Training Accuracy: 85.03%
# Epoch 170, Training Loss: 1.0035, Training Accuracy: 85.53%
# Epoch 171, Training Loss: 0.9713, Training Accuracy: 86.01%
# Validation Epoch 171/300:
# Validation Loss: 1.3636
# Validation Class Label Accuracy: 68.97%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 2
# Epoch 172, Training Loss: 1.0001, Training Accuracy: 85.65%
# Epoch 173, Training Loss: 0.9826, Training Accuracy: 85.42%
# Epoch 174, Training Loss: 0.9820, Training Accuracy: 85.99%
# Validation Epoch 174/300:
# Validation Loss: 1.3711
# Validation Class Label Accuracy: 70.48%
# Validation Concept Accuracy: 90.04%
# New Best Model Validation Accuracy: 70.47539616346955
# Epoch 175, Training Loss: 1.0060, Training Accuracy: 85.19%
# Epoch 176, Training Loss: 0.9939, Training Accuracy: 85.71%
# Epoch 177, Training Loss: 0.9686, Training Accuracy: 86.05%
# Validation Epoch 177/300:
# Validation Loss: 1.3739
# Validation Class Label Accuracy: 69.72%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 1
# Epoch 178, Training Loss: 1.0086, Training Accuracy: 84.88%
# Epoch 179, Training Loss: 0.9811, Training Accuracy: 86.21%
# Epoch 180, Training Loss: 0.9531, Training Accuracy: 86.34%
# Validation Epoch 180/300:
# Validation Loss: 1.3799
# Validation Class Label Accuracy: 68.89%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 181, Training Loss: 0.9902, Training Accuracy: 85.34%
# Epoch 182, Training Loss: 0.9753, Training Accuracy: 85.86%
# Epoch 183, Training Loss: 0.9592, Training Accuracy: 85.71%
# Validation Epoch 183/300:
# Validation Loss: 1.3751
# Validation Class Label Accuracy: 69.31%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 3
# Epoch 184, Training Loss: 0.9460, Training Accuracy: 85.90%
# Epoch 185, Training Loss: 0.9525, Training Accuracy: 86.03%
# Epoch 186, Training Loss: 0.9878, Training Accuracy: 85.53%
# Validation Epoch 186/300:
# Validation Loss: 1.3748
# Validation Class Label Accuracy: 69.72%
# Validation Concept Accuracy: 90.07%
# Epochs since last improvement: 4
# Epoch 187, Training Loss: 0.9806, Training Accuracy: 85.42%
# Epoch 188, Training Loss: 0.9510, Training Accuracy: 85.96%
# Epoch 189, Training Loss: 0.9597, Training Accuracy: 85.59%
# Validation Epoch 189/300:
# Validation Loss: 1.3784
# Validation Class Label Accuracy: 69.31%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 190, Training Loss: 0.9721, Training Accuracy: 86.03%
# Epoch 191, Training Loss: 0.9705, Training Accuracy: 85.71%
# Epoch 192, Training Loss: 0.9694, Training Accuracy: 86.11%
# Validation Epoch 192/300:
# Validation Loss: 1.3730
# Validation Class Label Accuracy: 69.47%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 193, Training Loss: 0.9766, Training Accuracy: 86.19%
# Epoch 194, Training Loss: 1.0164, Training Accuracy: 84.90%
# Epoch 195, Training Loss: 0.9588, Training Accuracy: 86.53%
# Validation Epoch 195/300:
# Validation Loss: 1.3687
# Validation Class Label Accuracy: 69.06%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 196, Training Loss: 0.9924, Training Accuracy: 85.51%
# Epoch 197, Training Loss: 0.9835, Training Accuracy: 85.86%
# Epoch 198, Training Loss: 0.9617, Training Accuracy: 85.99%
# Validation Epoch 198/300:
# Validation Loss: 1.3684
# Validation Class Label Accuracy: 69.64%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 3
# Epoch 199, Training Loss: 0.9921, Training Accuracy: 85.55%
# Epoch 200, Training Loss: 0.9898, Training Accuracy: 85.61%
# Epoch 201, Training Loss: 0.9711, Training Accuracy: 86.26%
# Validation Epoch 201/300:
# Validation Loss: 1.3712
# Validation Class Label Accuracy: 69.22%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# Epoch 202, Training Loss: 0.9647, Training Accuracy: 86.19%
# Epoch 203, Training Loss: 0.9803, Training Accuracy: 85.23%
# Epoch 204, Training Loss: 0.9918, Training Accuracy: 85.63%
# Validation Epoch 204/300:
# Validation Loss: 1.3703
# Validation Class Label Accuracy: 68.81%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 205, Training Loss: 0.9934, Training Accuracy: 85.80%
# Epoch 206, Training Loss: 0.9774, Training Accuracy: 85.76%
# Epoch 207, Training Loss: 1.0096, Training Accuracy: 85.11%
# Validation Epoch 207/300:
# Validation Loss: 1.3683
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 208, Training Loss: 0.9878, Training Accuracy: 85.42%
# Epoch 209, Training Loss: 0.9886, Training Accuracy: 85.28%
# Epoch 210, Training Loss: 0.9773, Training Accuracy: 85.65%
# Validation Epoch 210/300:
# Validation Loss: 1.3674
# Validation Class Label Accuracy: 69.89%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 211, Training Loss: 0.9689, Training Accuracy: 85.67%
# Epoch 212, Training Loss: 0.9731, Training Accuracy: 86.55%
# Epoch 213, Training Loss: 0.9920, Training Accuracy: 85.78%
# Validation Epoch 213/300:
# Validation Loss: 1.3691
# Validation Class Label Accuracy: 69.64%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 3
# Epoch 214, Training Loss: 0.9845, Training Accuracy: 85.63%
# Epoch 215, Training Loss: 0.9796, Training Accuracy: 85.30%
# Epoch 216, Training Loss: 0.9595, Training Accuracy: 86.11%
# Validation Epoch 216/300:
# Validation Loss: 1.3683
# Validation Class Label Accuracy: 69.47%
# Validation Concept Accuracy: 90.04%
# Epochs since last improvement: 4
# Epoch 217, Training Loss: 0.9829, Training Accuracy: 85.57%
# Epoch 218, Training Loss: 0.9829, Training Accuracy: 85.86%
# Epoch 219, Training Loss: 0.9632, Training Accuracy: 86.67%
# Validation Epoch 219/300:
# Validation Loss: 1.3682
# Validation Class Label Accuracy: 69.81%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 220, Training Loss: 0.9797, Training Accuracy: 85.80%
# Epoch 221, Training Loss: 0.9828, Training Accuracy: 84.80%
# Epoch 222, Training Loss: 0.9901, Training Accuracy: 85.67%
# Validation Epoch 222/300:
# Validation Loss: 1.3696
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 223, Training Loss: 0.9554, Training Accuracy: 86.07%
# Epoch 224, Training Loss: 0.9945, Training Accuracy: 85.57%
# Epoch 225, Training Loss: 1.0117, Training Accuracy: 85.28%
# Validation Epoch 225/300:
# Validation Loss: 1.3662
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 226, Training Loss: 0.9976, Training Accuracy: 85.19%
# Epoch 227, Training Loss: 0.9931, Training Accuracy: 85.17%
# Epoch 228, Training Loss: 0.9992, Training Accuracy: 86.24%
# Validation Epoch 228/300:
# Validation Loss: 1.3658
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 3
# Epoch 229, Training Loss: 0.9435, Training Accuracy: 86.17%
# Epoch 230, Training Loss: 1.0157, Training Accuracy: 85.15%
# Epoch 231, Training Loss: 0.9739, Training Accuracy: 85.90%
# Validation Epoch 231/300:
# Validation Loss: 1.3649
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# Epoch 232, Training Loss: 0.9958, Training Accuracy: 85.21%
# Epoch 233, Training Loss: 0.9935, Training Accuracy: 85.88%
# Epoch 234, Training Loss: 0.9800, Training Accuracy: 85.74%
# Validation Epoch 234/300:
# Validation Loss: 1.3643
# Validation Class Label Accuracy: 70.31%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 235, Training Loss: 0.9804, Training Accuracy: 85.55%
# Epoch 236, Training Loss: 1.0014, Training Accuracy: 85.44%
# Epoch 237, Training Loss: 1.0064, Training Accuracy: 85.36%
# Validation Epoch 237/300:
# Validation Loss: 1.3670
# Validation Class Label Accuracy: 69.72%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 238, Training Loss: 0.9545, Training Accuracy: 85.88%
# Epoch 239, Training Loss: 1.0151, Training Accuracy: 85.46%
# Epoch 240, Training Loss: 0.9692, Training Accuracy: 85.90%
# Validation Epoch 240/300:
# Validation Loss: 1.3679
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 241, Training Loss: 1.0000, Training Accuracy: 85.36%
# Epoch 242, Training Loss: 0.9586, Training Accuracy: 86.34%
# Epoch 243, Training Loss: 0.9989, Training Accuracy: 85.34%
# Validation Epoch 243/300:
# Validation Loss: 1.3660
# Validation Class Label Accuracy: 69.97%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 3
# Epoch 244, Training Loss: 0.9813, Training Accuracy: 85.57%
# Epoch 245, Training Loss: 0.9531, Training Accuracy: 85.94%
# Epoch 246, Training Loss: 0.9819, Training Accuracy: 85.96%
# Validation Epoch 246/300:
# Validation Loss: 1.3678
# Validation Class Label Accuracy: 70.23%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# Epoch 247, Training Loss: 0.9737, Training Accuracy: 86.09%
# Epoch 248, Training Loss: 0.9927, Training Accuracy: 85.65%
# Epoch 249, Training Loss: 1.0076, Training Accuracy: 85.07%
# Validation Epoch 249/300:
# Validation Loss: 1.3678
# Validation Class Label Accuracy: 70.23%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 250, Training Loss: 1.0258, Training Accuracy: 85.28%
# Epoch 251, Training Loss: 0.9691, Training Accuracy: 85.82%
# Epoch 252, Training Loss: 0.9977, Training Accuracy: 84.57%
# Validation Epoch 252/300:
# Validation Loss: 1.3679
# Validation Class Label Accuracy: 70.31%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 253, Training Loss: 0.9702, Training Accuracy: 86.49%
# Epoch 254, Training Loss: 0.9799, Training Accuracy: 85.59%
# Epoch 255, Training Loss: 1.0046, Training Accuracy: 85.23%
# Validation Epoch 255/300:
# Validation Loss: 1.3673
# Validation Class Label Accuracy: 69.72%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 256, Training Loss: 0.9722, Training Accuracy: 85.23%
# Epoch 257, Training Loss: 0.9949, Training Accuracy: 85.13%
# Epoch 258, Training Loss: 0.9766, Training Accuracy: 85.78%
# Validation Epoch 258/300:
# Validation Loss: 1.3690
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.06%
# Epochs since last improvement: 3
# Epoch 259, Training Loss: 1.0159, Training Accuracy: 85.19%
# Epoch 260, Training Loss: 0.9836, Training Accuracy: 85.34%
# Epoch 261, Training Loss: 1.0045, Training Accuracy: 85.51%
# Validation Epoch 261/300:
# Validation Loss: 1.3670
# Validation Class Label Accuracy: 70.23%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# Epoch 262, Training Loss: 0.9758, Training Accuracy: 86.19%
# Epoch 263, Training Loss: 0.9882, Training Accuracy: 85.57%
# Epoch 264, Training Loss: 0.9866, Training Accuracy: 85.63%
# Validation Epoch 264/300:
# Validation Loss: 1.3663
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 265, Training Loss: 0.9861, Training Accuracy: 85.84%
# Epoch 266, Training Loss: 0.9655, Training Accuracy: 86.28%
# Epoch 267, Training Loss: 0.9966, Training Accuracy: 86.11%
# Validation Epoch 267/300:
# Validation Loss: 1.3672
# Validation Class Label Accuracy: 69.97%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 268, Training Loss: 0.9807, Training Accuracy: 86.03%
# Epoch 269, Training Loss: 0.9806, Training Accuracy: 85.90%
# Epoch 270, Training Loss: 0.9870, Training Accuracy: 86.09%
# Validation Epoch 270/300:
# Validation Loss: 1.3684
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 271, Training Loss: 0.9839, Training Accuracy: 85.94%
# Epoch 272, Training Loss: 1.0001, Training Accuracy: 85.05%
# Epoch 273, Training Loss: 0.9863, Training Accuracy: 85.84%
# Validation Epoch 273/300:
# Validation Loss: 1.3670
# Validation Class Label Accuracy: 70.64%
# Validation Concept Accuracy: 90.05%
# New Best Model Validation Accuracy: 70.64220183486239
# Epoch 274, Training Loss: 0.9967, Training Accuracy: 85.15%
# Epoch 275, Training Loss: 0.9613, Training Accuracy: 85.99%
# Epoch 276, Training Loss: 0.9548, Training Accuracy: 86.03%
# Validation Epoch 276/300:
# Validation Loss: 1.3683
# Validation Class Label Accuracy: 70.48%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 277, Training Loss: 0.9723, Training Accuracy: 86.21%
# Epoch 278, Training Loss: 0.9903, Training Accuracy: 86.09%
# Epoch 279, Training Loss: 0.9527, Training Accuracy: 86.44%
# Validation Epoch 279/300:
# Validation Loss: 1.3677
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 280, Training Loss: 0.9918, Training Accuracy: 84.94%
# Epoch 281, Training Loss: 0.9750, Training Accuracy: 85.46%
# Epoch 282, Training Loss: 0.9815, Training Accuracy: 85.96%
# Validation Epoch 282/300:
# Validation Loss: 1.3663
# Validation Class Label Accuracy: 69.97%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 3
# Epoch 283, Training Loss: 0.9691, Training Accuracy: 85.76%
# Epoch 284, Training Loss: 0.9809, Training Accuracy: 86.05%
# Epoch 285, Training Loss: 0.9657, Training Accuracy: 86.26%
# Validation Epoch 285/300:
# Validation Loss: 1.3690
# Validation Class Label Accuracy: 69.72%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# Epoch 286, Training Loss: 0.9794, Training Accuracy: 85.38%
# Epoch 287, Training Loss: 0.9866, Training Accuracy: 85.53%
# Epoch 288, Training Loss: 1.0023, Training Accuracy: 85.32%
# Validation Epoch 288/300:
# Validation Loss: 1.3668
# Validation Class Label Accuracy: 70.06%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 5
# Soft reset of weights and reduce learning rate triggered
# Epoch 289, Training Loss: 1.0038, Training Accuracy: 85.38%
# Epoch 290, Training Loss: 1.0199, Training Accuracy: 84.46%
# Epoch 291, Training Loss: 0.9629, Training Accuracy: 86.24%
# Validation Epoch 291/300:
# Validation Loss: 1.3694
# Validation Class Label Accuracy: 70.39%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 1
# Epoch 292, Training Loss: 0.9955, Training Accuracy: 85.69%
# Epoch 293, Training Loss: 0.9739, Training Accuracy: 86.19%
# Epoch 294, Training Loss: 1.0020, Training Accuracy: 84.55%
# Validation Epoch 294/300:
# Validation Loss: 1.3662
# Validation Class Label Accuracy: 70.48%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 2
# Epoch 295, Training Loss: 0.9738, Training Accuracy: 85.74%
# Epoch 296, Training Loss: 0.9930, Training Accuracy: 85.71%
# Epoch 297, Training Loss: 0.9962, Training Accuracy: 85.34%
# Validation Epoch 297/300:
# Validation Loss: 1.3696
# Validation Class Label Accuracy: 69.89%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 3
# Epoch 298, Training Loss: 0.9983, Training Accuracy: 85.30%
# Epoch 299, Training Loss: 0.9960, Training Accuracy: 85.26%
# Epoch 300, Training Loss: 0.9911, Training Accuracy: 85.67%
# Validation Epoch 300/300:
# Validation Loss: 1.3658
# Validation Class Label Accuracy: 70.14%
# Validation Concept Accuracy: 90.05%
# Epochs since last improvement: 4
# CPU times: user 13min 13s, sys: 18min 34s, total: 31min 48s
# Wall time: 1h 16min 33s

# %%
from datetime import datetime

# Create timestamp string
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')  # Format: YYYYMMDD_HHMMSS


# Evaluate model
def evaluate_model(model, test_dataloader, device='cuda'):
    model.eval()  # Set to evaluation mode
    val_acc = 0.0
    concept_acc = 0.0
    val_total = 0
    concept_total = 0

    with torch.no_grad():
        for images, concepts, labels in test_dataloader:
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            predicted_labels, predicted_concepts = model(images, return_concepts=True)
            _, predicted = torch.max(predicted_labels.data, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()
            concept_total += concepts.size(0) * concepts.size(1)
            preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
            concept_acc += (preds == concepts).float().sum()

    val_acc = 100 * val_acc / val_total
    concept_acc = 100 * concept_acc / concept_total
    #print(f'Validation Loss: {running_loss/len(train_loader):.4f}')
    print(f'Test Class Label Accuracy: {val_acc:.2f}%')
    print(f'Test Concept Accuracy: {concept_acc:.2f}%')
    return val_acc, concept_acc


evaluate_model(model, test_loader)


best_state_dict = copy.deepcopy(model.state_dict())

# Save locally in this Colab
torch.save(best_state_dict, 'cub_model.pth')

# Save to Google Drive
torch.save(best_state_dict, os.path.join(save_dir,f'cub_model_{timestamp}.pth'))
# Out:
# Test Class Label Accuracy: 68.93%
# Test Concept Accuracy: 90.15%

# %%
def check_data_ranges(dataloader, name=""):
    label_min = float('inf')
    label_max = float('-inf')
    concept_mins = None  # Changed from list to None
    concept_maxs = None

    for _, concepts, labels in dataloader:
        label_min = min(label_min, labels.min().item())
        label_max = max(label_max, labels.max().item())

        if concept_mins is None:  # First iteration
            concept_mins = concepts.min(dim=0)[0]
            concept_maxs = concepts.max(dim=0)[0]
        else:
            concept_mins = torch.minimum(concept_mins, concepts.min(dim=0)[0])
            concept_maxs = torch.maximum(concept_maxs, concepts.max(dim=0)[0])

    print(f"\n{name} Dataset Stats:")
    print(f"Label range: {label_min} to {label_max}")
    print(f"Number of unique concepts: {len(concept_mins)}")

# Check both datasets
check_data_ranges(train_loader, "Train")
check_data_ranges(val_loader, "Val")
check_data_ranges(test_loader, "Test")
# Out:
# Train Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Val Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Test Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312

# %%
def check_image_stats(dataloader, name=""):
    first_batch = next(iter(dataloader))
    images, concepts, labels = first_batch

    print(f"\n{name} Dataset Image Stats:")
    print(f"Image tensor shape: {images.shape}")  # Should be [batch_size, channels, height, width]
    print(f"Image dtype: {images.dtype}")
    print(f"Value range: min={images.min():.3f}, max={images.max():.3f}")
    print(f"Mean: {images.mean():.3f}")
    print(f"Std: {images.std():.3f}")

    # Check for NaN/Inf
    print(f"Contains NaN: {torch.isnan(images).any()}")
    print(f"Contains Inf: {torch.isinf(images).any()}")

# Check both datasets
check_image_stats(train_loader, "Train")
check_image_stats(val_loader, "Val")
check_image_stats(test_loader, "Test")
# Out:
# Train Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.103
# Std: 1.056
# Contains NaN: False
# Contains Inf: False
#
# Val Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.114
# Std: 1.070
# Contains NaN: False
# Contains Inf: False
#
# Test Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.118
# Std: 1.048
# Contains NaN: False
# Contains Inf: False
