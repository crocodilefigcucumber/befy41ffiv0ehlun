# %% [markdown]
# # Implementing https://arxiv.org/pdf/2007.04612

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import numpy as np

import os
import random

import pandas as pd
import requests
from tqdm import tqdm
import tarfile
from torchvision import models


from PIL import Image

import itertools

from torch.cuda.amp import autocast

# %%
def set_seed(seed):
   torch.manual_seed(seed)
   torch.cuda.manual_seed(seed)
   torch.cuda.manual_seed_all(seed)
   np.random.seed(seed)
   random.seed(seed)
   torch.backends.cudnn.deterministic = True
   torch.backends.cudnn.benchmark = False

set_seed(42)  # Replace with your seed number

# %%
class BirdsDataset(Dataset):
    def __init__(self, images, concepts, labels, transform=None):
        assert type(concepts) == type(labels) == type(images) == list, (
          "concepts, labels, and images must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(images)))
        self.images = images
        self.concepts = concepts
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert("RGB")
        if self.transform:
            image = self.transform(image)
        concepts = self._convert_concepts_to_tensor(self.concepts[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return image, concepts, label


    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor


class CUBDataset(Dataset):
    """
    Create a PyTorch dataset from a list of image paths.

    Args:
        image_paths: List of paths to image files
        transform: Optional transform to be applied on images
                  (if None, will convert to tensor and normalize)
    """

    def __init__(self, image_paths, concepts, labels, transform=None):
      self.concepts = []
      self.labels = []
      self.images = []

      assert type(concepts) == type(labels) == type(image_paths) == list, (
        "concepts, labels, and image_paths must be of the same type, list. \nGot: %s, %s, %s" % (type(concepts), type(labels), type(image_paths)))

      assert len(image_paths) == len(concepts) == len(labels), (
        "Number of images, concepts, and labels must match")

      base_transforms = transforms.Compose(
      [
          transforms.Resize(size=(224, 224)),
          transforms.ToTensor(),
          transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
      ])

      # Default transform if none provided
      self.transform = transform if transform is not None else transforms.Compose([])

      for image_path, concept, label in zip(image_paths, concepts, labels):
        try:
          image = Image.open(image_path).convert('RGB')
        except Exception as e:
          print(f"Error loading image {image_path}: {str(e)}")
        # Apply base transforms
        image = base_transforms(image)
        self.images.append(image)

        self.concepts.append(self._convert_concepts_to_tensor(concept))
        self.labels.append(torch.tensor(label, dtype=torch.long))

    def _convert_concepts_to_tensor(self, concept_list):
        """
        Convert list of concept dictionaries to binary tensor.
        We use is_present field to create a binary vector.
        """
        # Create tensor of zeros
        concept_tensor = torch.zeros(312)

        # Fill in the binary values from is_present
        for i, concept_dict in enumerate(concept_list):
            concept_tensor[i] = 1.0 if concept_dict['is_present'] == 1.0 else 0.0

        return concept_tensor

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Load image
        image = self.transform(self.images[idx])
        label = self.labels[idx]
        concept = self.concepts[idx]

        return image, concept, label

# %%
def download_cub200_2011():
    """
    Downloads the CUB-200-2011 dataset and extracts it.
    Returns the path to the extracted dataset.
    """
    # Create a directory for the dataset
    base_dir = '/content/CUB_200_2011'
    dataset_dir = os.path.join(base_dir, 'CUB_200_2011')

    # Check if dataset already exists
    if os.path.exists(dataset_dir) and os.path.exists(os.path.join(dataset_dir, 'images.txt')):
        print("Dataset already downloaded and extracted.")
        return dataset_dir

    os.makedirs(base_dir, exist_ok=True)

    # URL for the dataset
    url = 'https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz'
    tgz_path = os.path.join(base_dir, 'CUB_200_2011.tgz')

    # Download only if not already downloaded
    if not os.path.exists(tgz_path):
        print("Downloading CUB-200-2011 dataset...")
        response = requests.get(url, stream=True)
        total_size = int(response.headers.get('content-length', 0))

        with open(tgz_path, 'wb') as f:
            for data in tqdm(response.iter_content(chunk_size=1024),
                            total=total_size//1024,
                            unit='KB'):
                f.write(data)

    # Extract only if not already extracted
    if not os.path.exists(dataset_dir):
        print("\nExtracting dataset...")
        with tarfile.open(tgz_path, 'r:gz') as tar:
            tar.extractall(base_dir)

    # Remove the downloaded tar file to save space
    if os.path.exists(tgz_path):
        os.remove(tgz_path)

    return dataset_dir

def read_txt_file(filepath, num_cols):
    """
    Safely read space-separated text files with a specific number of columns.
    """
    data = []
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) >= num_cols:
                data.append(parts[:num_cols])
    return pd.DataFrame(data)

def load_cub_data(data_dir):
    """
    Loads and organizes the CUB dataset metadata.
    Returns dictionaries for image paths, labels, and attribute data.
    """
    # Load image paths and labels using the safe reader
    images_df = read_txt_file(os.path.join(data_dir, 'images.txt'), 2)
    images_df.columns = ['image_id', 'image_path']
    images_df['image_id'] = images_df['image_id'].astype(int)

    labels_df = read_txt_file(os.path.join(data_dir, 'image_class_labels.txt'), 2)
    labels_df.columns = ['image_id', 'class_id']
    labels_df['image_id'] = labels_df['image_id'].astype(int)
    labels_df['class_id'] = labels_df['class_id'].astype(int)

    # Load train/test split
    train_test_df = read_txt_file(os.path.join(data_dir, 'train_test_split.txt'), 2)
    train_test_df.columns = ['image_id', 'is_training']
    train_test_df['image_id'] = train_test_df['image_id'].astype(int)
    train_test_df['is_training'] = train_test_df['is_training'].astype(int)

    # Load attributes using the safe reader
    attr_df = read_txt_file(os.path.join(data_dir, 'attributes/image_attribute_labels.txt'), 5)
    attr_df.columns = ['image_id', 'attribute_id', 'is_present', 'certainty', 'time']
    attr_df = attr_df.astype({
        'image_id': int,
        'attribute_id': int,
        'is_present': int,
        'certainty': int,
        'time': float
    })

    print("Merging")

    # Merge dataframes
    data = images_df.merge(labels_df, on='image_id')
    data = data.merge(train_test_df, on='image_id')

    print("Creating Dictionaries")
    # Create dictionaries
    image_paths = {row['image_id']: os.path.join(data_dir, 'images', row['image_path'])
                  for _, row in data.iterrows()}

    labels = {row['image_id']: row['class_id'] - 1  # Convert to 0-based indexing
             for _, row in data.iterrows()}

    train_test = {row['image_id']: row['is_training']
                  for _, row in data.iterrows()}

    # Organize attributes
    print("Organizing Attributes")
    # This is the slow part. Optimize...
    attributes = {}
    for _, row in attr_df.iterrows():
        image_id = row['image_id']
        if image_id not in attributes:
            attributes[image_id] = []
        attributes[image_id].append({
            'attribute_id': row['attribute_id'],
            'is_present': row['is_present'],
            'certainty': row['certainty']
        })

    return {
        'image_paths': image_paths,
        'labels': labels,
        'train_test_split': train_test,
        'attributes': attributes
    }

# %%
"""
# Download and extract the dataset
data_dir = download_cub200_2011()
print(f"\nDataset directory: {data_dir}")

# Load the dataset metadata
print("\nLoading dataset metadata...")
data = load_cub_data(data_dir)

num_classes = len(set(data['labels'].values()))

first_image_id = list(data['image_paths'].keys())[0]
num_concepts = len(data['attributes'][first_image_id])

# Print some statistics
print("\nDataset statistics:")
print(f"Total number of images: {len(data['image_paths'])}")
print(f"Number of training images: {sum(data['train_test_split'].values())}")

# a map of int id to class label 0 train, 1 test
print(f"Number of test images: {len(data['train_test_split']) - sum(data['train_test_split'].values())}")
print(f"Number of classes: {num_classes}")

# Example of accessing data for first image
print(f"\nExample data for image {first_image_id}:")
print(f"Image path: {data['image_paths'][first_image_id]}")
print(f"Class label: {data['labels'][first_image_id]}")
print(f"Is training: {data['train_test_split'][first_image_id]}")
print(f"Number of concepts: {num_concepts}")

"""
# Out:
# '\n# Download and extract the dataset\ndata_dir = download_cub200_2011()\nprint(f"\nDataset directory: {data_dir}")\n\n# Load the dataset metadata\nprint("\nLoading dataset metadata...")\ndata = load_cub_data(data_dir)\n\nnum_classes = len(set(data[\'labels\'].values()))\n\nfirst_image_id = list(data[\'image_paths\'].keys())[0]\nnum_concepts = len(data[\'attributes\'][first_image_id])\n\n# Print some statistics\nprint("\nDataset statistics:")\nprint(f"Total number of images: {len(data[\'image_paths\'])}")\nprint(f"Number of training images: {sum(data[\'train_test_split\'].values())}")\n\n# a map of int id to class label 0 train, 1 test\nprint(f"Number of test images: {len(data[\'train_test_split\']) - sum(data[\'train_test_split\'].values())}")\nprint(f"Number of classes: {num_classes}")\n\n# Example of accessing data for first image\nprint(f"\nExample data for image {first_image_id}:")\nprint(f"Image path: {data[\'image_paths\'][first_image_id]}")\nprint(f"Class label: {data[\'labels\'][first_image_id]}")\nprint(f"Is training: {data[\'train_test_split\'][first_image_id]}")\nprint(f"Number of concepts: {num_concepts}")\n\n'

# %%
import copy

class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# Define the concept bottleneck model
class ConceptBottleneckModel(nn.Module):
    def __init__(self, num_concepts=10, num_classes=200):
        super(ConceptBottleneckModel, self).__init__()
        self.encoder_res = models.resnet18(weights=None)
        self.encoder_res.load_state_dict(
            torch.load("/content/resnet18-5c106cde.pth")
        )
        #n_features = self.encoder_res.fc.in_features
        self.encoder_res.fc = Identity()
        self.features = nn.Sequential(self.encoder_res)

        # Concept predictor
        self.concept_predictor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 1024), # this was (512, 256)
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_concepts),
            nn.Sigmoid()
        )


        # Class predictor

        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, num_classes)
        )

        """
        self.class_predictor = nn.Sequential(
            nn.Linear(num_concepts, 2048),
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, num_classes)
        )
        """

    def forward(self, x, return_concepts=False):
        features = self.features(x)
        concepts = self.concept_predictor(features)
        outputs = self.class_predictor(concepts)

        if return_concepts:
            return outputs, concepts
        return outputs

# Training function
def train_model(model,
                train_loader,
                val_loader,
                num_epochs=10,
                validation_interval=1,
                lr=0.001,
                lambda_=1.0,
                device='cuda'):
    criterion_concepts = nn.BCELoss()
    criterion_classes = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    #scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5, verbose=True)
    model = model.to(device)
    best_val_acc = 0.0
    #epoch_since_improvement_limit = 5
    #epochs_since_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        training_loss = 0.0
        train_correct = 0
        train_total = 0

        for i, (images, concepts, labels) in enumerate(train_loader):
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # Forward pass
            predicted_classes, predicted_concepts = model(images, return_concepts=True)

            # Calculate losses
            concept_loss = criterion_concepts(predicted_concepts, concepts)
            class_loss = criterion_classes(predicted_classes, labels)
            #print("predicted_classes = %s" % predicted_classes)
            #print("labels = %s" % labels)

            total_loss = class_loss + lambda_ * concept_loss
            training_loss += total_loss
            train_total += labels.size(0)
            _, predicted = torch.max(predicted_classes.data, 1)
            train_correct += (predicted == labels).sum().item()

            #print("Total Loss is: %s, Class Loss is: %s, Concept Loss: %s" % (total_loss.item(), class_loss.item(), concept_loss.item()))
            # Backward pass
            total_loss.backward()
            optimizer.step()

        # Print epoch-level metrics
        avg_train_loss = training_loss / len(train_loader)
        train_acc = 100 * train_correct / train_total
        print(f'Epoch {epoch+1}, Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_acc:.2f}%')

        if (epoch + 1) % validation_interval == 0:
          # Validation
          model.eval()
          val_acc = 0.0
          concept_acc = 0.0
          val_total = 0
          concept_total = 0
          validation_loss = 0

          with torch.no_grad():
              for images, concepts, labels in val_loader:
                  images = images.to(device)
                  concepts = concepts.to(device)
                  labels = labels.to(device)

                  predicted_labels, predicted_concepts = model(images, return_concepts=True)
                  """
                  # 1. Check your class predictions range before CrossEntropyLoss
                  print("predicted_labels min %s max %s" %(torch.min(predicted_labels), torch.max(predicted_labels)))
                  # Should be reasonable logit values, not extreme

                  # 2. Verify label format
                  print("labels min %s max %s" % (labels.min(), labels.max()))  # Should be 0 to num_classes-1

                  # 3. Check concept predictions before BCE
                  print("predicted_concepts min %s max %s" % (torch.min(predicted_concepts), torch.max(predicted_concepts)))
                  # Should be between 0-1 after sigmoid
                  """

                  _, predicted = torch.max(predicted_labels.data, 1)
                  val_total += labels.size(0)
                  val_acc += (predicted == labels).sum().item()
                  concept_total += concepts.size(0) * concepts.size(1)
                  preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
                  concept_acc += (preds == concepts).float().sum()

                  concept_loss = criterion_concepts(predicted_concepts, concepts)
                  class_loss = criterion_classes(predicted_labels, labels)
                  validation_loss += class_loss + lambda_ * concept_loss
          val_acc = 100 * val_acc / val_total
          concept_acc = 100 * concept_acc / concept_total
          print(f'Validation Epoch {epoch+1}/{num_epochs}:')
          print(f'Validation Loss: {validation_loss/len(val_loader):.4f}')
          print(f'Validation Class Label Accuracy: {val_acc:.2f}%')
          print(f'Validation Concept Accuracy: {concept_acc:.2f}%')
          #scheduler.step(validation_loss)

          """
          if val_acc > best_val_acc:
            print("New Best Model Validation Accuracy: %s" % val_acc)
            best_val_acc = val_acc
            best_state_dict = copy.deepcopy(model.state_dict())
            torch.save(best_state_dict, 'best_model.pth')
          else:
            epochs_since_improvement+=1
          if epochs_since_improvement >= epoch_since_improvement_limit:
            print("Soft reset of weights and reduce learning rate triggered")
            model.load_state_dict(best_state_dict)
            scheduler.step()
          """

# %%
#print(data['train_test_split'])
#print(data['train_test_split'].values())

#print(data['image_paths'])

#print(data['attributes'])
#print(data['attributes'][1])

#print(data)

# %%
def get_data_dict():
  data_dir = download_cub200_2011()
  data = load_cub_data(data_dir)
  return data


def get_train_val_test_datasets(data):

  # Initialize the split dictionary
  splits = {}

  # Get indices where value in dict is 1 (training)
  train_indices = [k for k, v in data['train_test_split'].items() if v == 1]

  # Randomly shuffle these indices
  shuffled_indices = np.random.permutation(train_indices)

  # Calculate split point for 80/20 split of training data
  n_train = int(len(train_indices) * 0.8)

  # First set all indices in original dict to 'test'
  for idx in data['train_test_split'].keys():
      splits[idx] = 'test'

  # Update training indices
  for idx in shuffled_indices[:n_train]:
      splits[idx] = 'train'

  # Update validation indices
  for idx in shuffled_indices[n_train:]:
      splits[idx] = 'val'

  data['split'] = splits


  # First get sorted IDs for train and test
  train_ids = sorted([id for id, split in data['split'].items() if split == "train"])
  val_ids = sorted([id for id, split in data['split'].items() if split == "val"])
  test_ids = sorted([id for id, split in data['split'].items() if split == "test"])

  print(len(train_ids))
  print(len(val_ids))
  print(len(test_ids))

  # Following the transformations from CBM paper
  resol = 299


  train_transforms = transforms.Compose(
    [
    #    transforms.ColorJitter(brightness=32 / 255, saturation=(0.5, 1.5)),
   #     transforms.RandomResizedCrop(resol),
    #    transforms.RandomHorizontalFlip(),
    ]
  )

  val_transforms = transforms.Compose([])

  test_transforms = transforms.Compose([
      #transforms.CenterCrop(resol)
  ])


  # Create training dataset using the sorted train IDs
  train_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in train_ids],
      concepts=[data['attributes'][id] for id in train_ids],
      labels=[data['labels'][id] for id in train_ids],
      transform=train_transforms
  )

  val_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in val_ids],
      concepts=[data['attributes'][id] for id in val_ids],
      labels=[data['labels'][id] for id in val_ids],
      transform=val_transforms
  )

  # Create validation dataset using the sorted test IDs
  test_dataset = CUBDataset(
      image_paths=[data['image_paths'][id] for id in test_ids],
      concepts=[data['attributes'][id] for id in test_ids],
      labels=[data['labels'][id] for id in test_ids],
      transform=test_transforms
  )
   # Verify the split
  print(f"Training samples: {len(train_dataset)}")
  print(f"Validation samples: {len(val_dataset)}")
  print(f"Test samples: {len(test_dataset)}")

  return train_dataset, val_dataset, test_dataset



def get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size):

  import multiprocessing as mp

  num_cpus = mp.cpu_count()
  num_workers = num_cpus - 2
  print(f"Number of CPUs: {num_cpus}")
  print(f"Number of workers: {num_workers}")

  train_loader = DataLoader(
      train_dataset,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True
  )

  val_loader = DataLoader(
      val_dataset,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True
  )

  test_loader = DataLoader(
      test_dataset,
      batch_size=batch_size,
      shuffle=False,  # No need to shuffle validation data
      num_workers=num_workers
  )
  return train_loader, val_loader, test_loader

# %%
# %%time
data_dict = get_data_dict()
print("Creating Datasets")
train_dataset, val_dataset, test_dataset = get_train_val_test_datasets(data_dict)
print("Creating Dataloaders")
train_loader, val_loader, test_loader = get_train_val_test_loaders(train_dataset, val_dataset, test_dataset, batch_size=512)
# Out:
# Downloading CUB-200-2011 dataset...
# 1123619KB [01:19, 14066.34KB/s]
# Extracting dataset...
# Merging
# Creating Dictionaries
# Organizing Attributes
# Creating Datasets
# 4795
# 1199
# 5794
# Training samples: 4795
# Validation samples: 1199
# Test samples: 5794
# Creating Dataloaders
# Number of CPUs: 12
# Number of workers: 10
# CPU times: user 9min 4s, sys: 12.2 s, total: 9min 16s
# Wall time: 5min 10s

# %%
# %%time
num_concepts = 312
num_classes = 200
model = ConceptBottleneckModel(num_concepts=num_concepts, num_classes=num_classes)
#model = model.to(torch.bfloat16).to('cuda')

#model = model.to(torch.bfloat16)


# lambda_ controls the balance between the class loss and the concept loss. A small lambda shrinks the importance of the concept loss.
# Out:
# CPU times: user 225 ms, sys: 104 ms, total: 329 ms
# Wall time: 291 ms
# <ipython-input-6-9e16dc11a25a>:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load("/content/resnet18-5c106cde.pth")

# %%
# %%time

train_model(model, train_loader, val_loader, validation_interval=10, lr=0.0001, lambda_=1, num_epochs=300)
# Out:
# Epoch 1, Training Loss: 5.9874, Training Accuracy: 0.50%
# Epoch 2, Training Loss: 5.8314, Training Accuracy: 1.15%
# Epoch 3, Training Loss: 5.7225, Training Accuracy: 1.38%
# Epoch 4, Training Loss: 5.6476, Training Accuracy: 2.69%
# Epoch 5, Training Loss: 5.5873, Training Accuracy: 3.94%
# Epoch 6, Training Loss: 5.5371, Training Accuracy: 4.80%
# Epoch 7, Training Loss: 5.4825, Training Accuracy: 7.86%
# Epoch 8, Training Loss: 5.4088, Training Accuracy: 9.13%
# Epoch 9, Training Loss: 5.3088, Training Accuracy: 10.07%
# Epoch 10, Training Loss: 5.1648, Training Accuracy: 10.66%
# Validation Epoch 10/300:
# Validation Loss: 5.1690
# Validation Class Label Accuracy: 5.34%
# Validation Concept Accuracy: 88.75%
# Epoch 11, Training Loss: 4.9670, Training Accuracy: 11.39%
# Epoch 12, Training Loss: 4.7328, Training Accuracy: 12.55%
# Epoch 13, Training Loss: 4.4701, Training Accuracy: 15.70%
# Epoch 14, Training Loss: 4.2169, Training Accuracy: 20.08%
# Epoch 15, Training Loss: 3.9735, Training Accuracy: 24.98%
# Epoch 16, Training Loss: 3.7391, Training Accuracy: 29.89%
# Epoch 17, Training Loss: 3.5194, Training Accuracy: 35.85%
# Epoch 18, Training Loss: 3.3217, Training Accuracy: 40.35%
# Epoch 19, Training Loss: 3.1276, Training Accuracy: 45.21%
# Epoch 20, Training Loss: 2.9315, Training Accuracy: 50.68%
# Validation Epoch 20/300:
# Validation Loss: 3.4191
# Validation Class Label Accuracy: 29.77%
# Validation Concept Accuracy: 77.31%
# Epoch 21, Training Loss: 2.7672, Training Accuracy: 55.91%
# Epoch 22, Training Loss: 2.5975, Training Accuracy: 60.13%
# Epoch 23, Training Loss: 2.4295, Training Accuracy: 65.32%
# Epoch 24, Training Loss: 2.2763, Training Accuracy: 70.80%
# Epoch 25, Training Loss: 2.1301, Training Accuracy: 73.62%
# Epoch 26, Training Loss: 1.9884, Training Accuracy: 78.77%
# Epoch 27, Training Loss: 1.8585, Training Accuracy: 81.71%
# Epoch 28, Training Loss: 1.7254, Training Accuracy: 85.63%
# Epoch 29, Training Loss: 1.6168, Training Accuracy: 88.55%
# Epoch 30, Training Loss: 1.5053, Training Accuracy: 90.80%
# Validation Epoch 30/300:
# Validation Loss: 2.6515
# Validation Class Label Accuracy: 44.87%
# Validation Concept Accuracy: 75.05%
# Epoch 31, Training Loss: 1.4102, Training Accuracy: 92.66%
# Epoch 32, Training Loss: 1.3222, Training Accuracy: 94.22%
# Epoch 33, Training Loss: 1.2346, Training Accuracy: 95.89%
# Epoch 34, Training Loss: 1.1582, Training Accuracy: 96.87%
# Epoch 35, Training Loss: 1.0944, Training Accuracy: 97.85%
# Epoch 36, Training Loss: 1.0365, Training Accuracy: 98.23%
# Epoch 37, Training Loss: 0.9841, Training Accuracy: 98.81%
# Epoch 38, Training Loss: 0.9284, Training Accuracy: 99.00%
# Epoch 39, Training Loss: 0.8804, Training Accuracy: 99.27%
# Epoch 40, Training Loss: 0.8475, Training Accuracy: 99.48%
# Validation Epoch 40/300:
# Validation Loss: 2.3952
# Validation Class Label Accuracy: 48.79%
# Validation Concept Accuracy: 76.97%
# Epoch 41, Training Loss: 0.8095, Training Accuracy: 99.67%
# Epoch 42, Training Loss: 0.7798, Training Accuracy: 99.73%
# Epoch 43, Training Loss: 0.7564, Training Accuracy: 99.87%
# Epoch 44, Training Loss: 0.7275, Training Accuracy: 99.83%
# Epoch 45, Training Loss: 0.7056, Training Accuracy: 99.87%
# Epoch 46, Training Loss: 0.6836, Training Accuracy: 99.94%
# Epoch 47, Training Loss: 0.6636, Training Accuracy: 99.96%
# Epoch 48, Training Loss: 0.6460, Training Accuracy: 99.98%
# Epoch 49, Training Loss: 0.6314, Training Accuracy: 99.90%
# Epoch 50, Training Loss: 0.6134, Training Accuracy: 99.94%
# Validation Epoch 50/300:
# Validation Loss: 2.2947
# Validation Class Label Accuracy: 51.46%
# Validation Concept Accuracy: 80.28%
# Epoch 51, Training Loss: 0.5995, Training Accuracy: 99.96%
# Epoch 52, Training Loss: 0.5868, Training Accuracy: 99.96%
# Epoch 53, Training Loss: 0.5742, Training Accuracy: 99.98%
# Epoch 54, Training Loss: 0.5639, Training Accuracy: 99.98%
# Epoch 55, Training Loss: 0.5516, Training Accuracy: 99.98%
# Epoch 56, Training Loss: 0.5430, Training Accuracy: 100.00%
# Epoch 57, Training Loss: 0.5324, Training Accuracy: 100.00%
# Epoch 58, Training Loss: 0.5250, Training Accuracy: 99.96%
# Epoch 59, Training Loss: 0.5170, Training Accuracy: 99.98%
# Epoch 60, Training Loss: 0.5085, Training Accuracy: 99.98%
# Validation Epoch 60/300:
# Validation Loss: 2.2720
# Validation Class Label Accuracy: 51.04%
# Validation Concept Accuracy: 82.67%
# Epoch 61, Training Loss: 0.5018, Training Accuracy: 100.00%
# Epoch 62, Training Loss: 0.4912, Training Accuracy: 100.00%
# Epoch 63, Training Loss: 0.4858, Training Accuracy: 99.98%
# Epoch 64, Training Loss: 0.4783, Training Accuracy: 100.00%
# Epoch 65, Training Loss: 0.4719, Training Accuracy: 100.00%
# Epoch 66, Training Loss: 0.4685, Training Accuracy: 100.00%
# Epoch 67, Training Loss: 0.4601, Training Accuracy: 99.98%
# Epoch 68, Training Loss: 0.4562, Training Accuracy: 100.00%
# Epoch 69, Training Loss: 0.4497, Training Accuracy: 100.00%
# Epoch 70, Training Loss: 0.4478, Training Accuracy: 100.00%
# Validation Epoch 70/300:
# Validation Loss: 2.2262
# Validation Class Label Accuracy: 51.63%
# Validation Concept Accuracy: 84.59%
# Epoch 71, Training Loss: 0.4410, Training Accuracy: 100.00%
# Epoch 72, Training Loss: 0.4368, Training Accuracy: 100.00%
# Epoch 73, Training Loss: 0.4336, Training Accuracy: 100.00%
# Epoch 74, Training Loss: 0.4280, Training Accuracy: 100.00%
# Epoch 75, Training Loss: 0.4225, Training Accuracy: 100.00%
# Epoch 76, Training Loss: 0.4198, Training Accuracy: 100.00%
# Epoch 77, Training Loss: 0.4147, Training Accuracy: 100.00%
# Epoch 78, Training Loss: 0.4117, Training Accuracy: 100.00%
# Epoch 79, Training Loss: 0.4099, Training Accuracy: 100.00%
# Epoch 80, Training Loss: 0.4041, Training Accuracy: 100.00%
# Validation Epoch 80/300:
# Validation Loss: 2.2262
# Validation Class Label Accuracy: 51.88%
# Validation Concept Accuracy: 85.83%
# Epoch 81, Training Loss: 0.4008, Training Accuracy: 100.00%
# Epoch 82, Training Loss: 0.3975, Training Accuracy: 100.00%
# Epoch 83, Training Loss: 0.3947, Training Accuracy: 100.00%
# Epoch 84, Training Loss: 0.3922, Training Accuracy: 100.00%
# Epoch 85, Training Loss: 0.3874, Training Accuracy: 100.00%
# Epoch 86, Training Loss: 0.3859, Training Accuracy: 100.00%
# Epoch 87, Training Loss: 0.3815, Training Accuracy: 100.00%
# Epoch 88, Training Loss: 0.3794, Training Accuracy: 100.00%
# Epoch 89, Training Loss: 0.3754, Training Accuracy: 99.98%
# Epoch 90, Training Loss: 0.3731, Training Accuracy: 100.00%
# Validation Epoch 90/300:
# Validation Loss: 2.2498
# Validation Class Label Accuracy: 51.96%
# Validation Concept Accuracy: 86.81%
# Epoch 91, Training Loss: 0.3701, Training Accuracy: 100.00%
# Epoch 92, Training Loss: 0.3687, Training Accuracy: 100.00%
# Epoch 93, Training Loss: 0.3654, Training Accuracy: 100.00%
# Epoch 94, Training Loss: 0.3635, Training Accuracy: 100.00%
# Epoch 95, Training Loss: 0.3602, Training Accuracy: 100.00%
# Epoch 96, Training Loss: 0.3598, Training Accuracy: 100.00%
# Epoch 97, Training Loss: 0.3573, Training Accuracy: 100.00%
# Epoch 98, Training Loss: 0.3537, Training Accuracy: 100.00%
# Epoch 99, Training Loss: 0.3511, Training Accuracy: 100.00%
# Epoch 100, Training Loss: 0.3496, Training Accuracy: 100.00%
# Validation Epoch 100/300:
# Validation Loss: 2.2029
# Validation Class Label Accuracy: 51.21%
# Validation Concept Accuracy: 87.62%
# Epoch 101, Training Loss: 0.3475, Training Accuracy: 100.00%
# Epoch 102, Training Loss: 0.3445, Training Accuracy: 100.00%
# Epoch 103, Training Loss: 0.3430, Training Accuracy: 100.00%
# Epoch 104, Training Loss: 0.3407, Training Accuracy: 100.00%
# Epoch 105, Training Loss: 0.3397, Training Accuracy: 100.00%
# Epoch 106, Training Loss: 0.3368, Training Accuracy: 100.00%
# Epoch 107, Training Loss: 0.3352, Training Accuracy: 100.00%
# Epoch 108, Training Loss: 0.3329, Training Accuracy: 100.00%
# Epoch 109, Training Loss: 0.3309, Training Accuracy: 100.00%
# Epoch 110, Training Loss: 0.3306, Training Accuracy: 99.96%
# Validation Epoch 110/300:
# Validation Loss: 2.1873
# Validation Class Label Accuracy: 52.54%
# Validation Concept Accuracy: 88.25%
# Epoch 111, Training Loss: 0.3297, Training Accuracy: 99.98%
# Epoch 112, Training Loss: 0.3268, Training Accuracy: 100.00%
# Epoch 113, Training Loss: 0.3242, Training Accuracy: 100.00%
# Epoch 114, Training Loss: 0.3229, Training Accuracy: 100.00%
# Epoch 115, Training Loss: 0.3222, Training Accuracy: 100.00%
# Epoch 116, Training Loss: 0.3203, Training Accuracy: 100.00%
# Epoch 117, Training Loss: 0.3184, Training Accuracy: 100.00%
# Epoch 118, Training Loss: 0.3165, Training Accuracy: 100.00%
# Epoch 119, Training Loss: 0.3159, Training Accuracy: 100.00%
# Epoch 120, Training Loss: 0.3138, Training Accuracy: 100.00%
# Validation Epoch 120/300:
# Validation Loss: 2.1982
# Validation Class Label Accuracy: 51.96%
# Validation Concept Accuracy: 88.64%
# Epoch 121, Training Loss: 0.3116, Training Accuracy: 100.00%
# Epoch 122, Training Loss: 0.3110, Training Accuracy: 100.00%
# Epoch 123, Training Loss: 0.3081, Training Accuracy: 100.00%
# Epoch 124, Training Loss: 0.3070, Training Accuracy: 100.00%
# Epoch 125, Training Loss: 0.3073, Training Accuracy: 100.00%
# Epoch 126, Training Loss: 0.3049, Training Accuracy: 100.00%
# Epoch 127, Training Loss: 0.3042, Training Accuracy: 100.00%
# Epoch 128, Training Loss: 0.3027, Training Accuracy: 99.98%
# Epoch 129, Training Loss: 0.3017, Training Accuracy: 100.00%
# Epoch 130, Training Loss: 0.3002, Training Accuracy: 100.00%
# Validation Epoch 130/300:
# Validation Loss: 2.2182
# Validation Class Label Accuracy: 51.21%
# Validation Concept Accuracy: 89.10%
# Epoch 131, Training Loss: 0.2981, Training Accuracy: 100.00%
# Epoch 132, Training Loss: 0.2975, Training Accuracy: 100.00%
# Epoch 133, Training Loss: 0.2959, Training Accuracy: 100.00%
# Epoch 134, Training Loss: 0.2937, Training Accuracy: 100.00%
# Epoch 135, Training Loss: 0.2930, Training Accuracy: 100.00%
# Epoch 136, Training Loss: 0.2916, Training Accuracy: 100.00%
# Epoch 137, Training Loss: 0.2909, Training Accuracy: 100.00%
# Epoch 138, Training Loss: 0.2898, Training Accuracy: 99.98%
# Epoch 139, Training Loss: 0.2882, Training Accuracy: 100.00%
# Epoch 140, Training Loss: 0.2865, Training Accuracy: 100.00%
# Validation Epoch 140/300:
# Validation Loss: 2.1980
# Validation Class Label Accuracy: 52.46%
# Validation Concept Accuracy: 89.40%
# Epoch 141, Training Loss: 0.2863, Training Accuracy: 100.00%
# Epoch 142, Training Loss: 0.2845, Training Accuracy: 100.00%
# Epoch 143, Training Loss: 0.2851, Training Accuracy: 100.00%
# Epoch 144, Training Loss: 0.2819, Training Accuracy: 100.00%
# Epoch 145, Training Loss: 0.2808, Training Accuracy: 100.00%
# Epoch 146, Training Loss: 0.2800, Training Accuracy: 100.00%
# Epoch 147, Training Loss: 0.2792, Training Accuracy: 100.00%
# Epoch 148, Training Loss: 0.2783, Training Accuracy: 100.00%
# Epoch 149, Training Loss: 0.2765, Training Accuracy: 100.00%
# Epoch 150, Training Loss: 0.2752, Training Accuracy: 100.00%
# Validation Epoch 150/300:
# Validation Loss: 2.2186
# Validation Class Label Accuracy: 52.04%
# Validation Concept Accuracy: 89.59%
# Epoch 151, Training Loss: 0.2744, Training Accuracy: 100.00%
# Epoch 152, Training Loss: 0.2733, Training Accuracy: 100.00%
# Epoch 153, Training Loss: 0.2734, Training Accuracy: 100.00%
# Epoch 154, Training Loss: 0.2719, Training Accuracy: 100.00%
# Epoch 155, Training Loss: 0.2715, Training Accuracy: 100.00%
# Epoch 156, Training Loss: 0.2691, Training Accuracy: 100.00%
# Epoch 157, Training Loss: 0.2691, Training Accuracy: 100.00%
# Epoch 158, Training Loss: 0.2677, Training Accuracy: 100.00%
# Epoch 159, Training Loss: 0.2670, Training Accuracy: 100.00%
# Epoch 160, Training Loss: 0.2670, Training Accuracy: 100.00%
# Validation Epoch 160/300:
# Validation Loss: 2.2337
# Validation Class Label Accuracy: 52.21%
# Validation Concept Accuracy: 89.78%
# Epoch 161, Training Loss: 0.2654, Training Accuracy: 100.00%
# Epoch 162, Training Loss: 0.2652, Training Accuracy: 99.98%
# Epoch 163, Training Loss: 0.2630, Training Accuracy: 100.00%
# Epoch 164, Training Loss: 0.2622, Training Accuracy: 100.00%
# Epoch 165, Training Loss: 0.2618, Training Accuracy: 100.00%
# Epoch 166, Training Loss: 0.2611, Training Accuracy: 100.00%
# Epoch 167, Training Loss: 0.2599, Training Accuracy: 100.00%
# Epoch 168, Training Loss: 0.2593, Training Accuracy: 100.00%
# Epoch 169, Training Loss: 0.2588, Training Accuracy: 100.00%
# Epoch 170, Training Loss: 0.2579, Training Accuracy: 100.00%
# Validation Epoch 170/300:
# Validation Loss: 2.2131
# Validation Class Label Accuracy: 51.79%
# Validation Concept Accuracy: 89.97%
# Epoch 171, Training Loss: 0.2573, Training Accuracy: 100.00%
# Epoch 172, Training Loss: 0.2579, Training Accuracy: 99.98%
# Epoch 173, Training Loss: 0.2558, Training Accuracy: 100.00%
# Epoch 174, Training Loss: 0.2548, Training Accuracy: 100.00%
# Epoch 175, Training Loss: 0.2541, Training Accuracy: 100.00%
# Epoch 176, Training Loss: 0.2536, Training Accuracy: 100.00%
# Epoch 177, Training Loss: 0.2520, Training Accuracy: 100.00%
# Epoch 178, Training Loss: 0.2514, Training Accuracy: 100.00%
# Epoch 179, Training Loss: 0.2503, Training Accuracy: 100.00%
# Epoch 180, Training Loss: 0.2491, Training Accuracy: 100.00%
# Validation Epoch 180/300:
# Validation Loss: 2.2108
# Validation Class Label Accuracy: 51.96%
# Validation Concept Accuracy: 90.11%
# Epoch 181, Training Loss: 0.2482, Training Accuracy: 100.00%
# Epoch 182, Training Loss: 0.2473, Training Accuracy: 100.00%
# Epoch 183, Training Loss: 0.2463, Training Accuracy: 100.00%
# Epoch 184, Training Loss: 0.2458, Training Accuracy: 100.00%
# Epoch 185, Training Loss: 0.2449, Training Accuracy: 100.00%
# Epoch 186, Training Loss: 0.2440, Training Accuracy: 100.00%
# Epoch 187, Training Loss: 0.2435, Training Accuracy: 100.00%
# Epoch 188, Training Loss: 0.2419, Training Accuracy: 100.00%
# Epoch 189, Training Loss: 0.2416, Training Accuracy: 99.98%
# Epoch 190, Training Loss: 0.2419, Training Accuracy: 99.98%
# Validation Epoch 190/300:
# Validation Loss: 2.2406
# Validation Class Label Accuracy: 52.79%
# Validation Concept Accuracy: 90.19%
# Epoch 191, Training Loss: 0.2403, Training Accuracy: 100.00%
# Epoch 192, Training Loss: 0.2392, Training Accuracy: 100.00%
# Epoch 193, Training Loss: 0.2399, Training Accuracy: 99.98%
# Epoch 194, Training Loss: 0.2391, Training Accuracy: 99.98%
# Epoch 195, Training Loss: 0.2395, Training Accuracy: 100.00%
# Epoch 196, Training Loss: 0.2379, Training Accuracy: 100.00%
# Epoch 197, Training Loss: 0.2372, Training Accuracy: 99.98%
# Epoch 198, Training Loss: 0.2361, Training Accuracy: 100.00%
# Epoch 199, Training Loss: 0.2361, Training Accuracy: 99.98%
# Epoch 200, Training Loss: 0.2350, Training Accuracy: 100.00%
# Validation Epoch 200/300:
# Validation Loss: 2.2191
# Validation Class Label Accuracy: 51.88%
# Validation Concept Accuracy: 90.28%
# Epoch 201, Training Loss: 0.2350, Training Accuracy: 100.00%
# Epoch 202, Training Loss: 0.2336, Training Accuracy: 100.00%
# Epoch 203, Training Loss: 0.2333, Training Accuracy: 100.00%
# Epoch 204, Training Loss: 0.2318, Training Accuracy: 100.00%
# Epoch 205, Training Loss: 0.2324, Training Accuracy: 99.98%
# Epoch 206, Training Loss: 0.2323, Training Accuracy: 100.00%
# Epoch 207, Training Loss: 0.2319, Training Accuracy: 100.00%
# Epoch 208, Training Loss: 0.2311, Training Accuracy: 99.98%
# Epoch 209, Training Loss: 0.2302, Training Accuracy: 100.00%
# Epoch 210, Training Loss: 0.2289, Training Accuracy: 100.00%
# Validation Epoch 210/300:
# Validation Loss: 2.2592
# Validation Class Label Accuracy: 52.71%
# Validation Concept Accuracy: 90.31%
# Epoch 211, Training Loss: 0.2276, Training Accuracy: 100.00%
# Epoch 212, Training Loss: 0.2281, Training Accuracy: 100.00%
# Epoch 213, Training Loss: 0.2270, Training Accuracy: 100.00%
# Epoch 214, Training Loss: 0.2261, Training Accuracy: 100.00%
# Epoch 215, Training Loss: 0.2265, Training Accuracy: 100.00%
# Epoch 216, Training Loss: 0.2253, Training Accuracy: 100.00%
# Epoch 217, Training Loss: 0.2246, Training Accuracy: 100.00%
# Epoch 218, Training Loss: 0.2236, Training Accuracy: 100.00%
# Epoch 219, Training Loss: 0.2230, Training Accuracy: 100.00%
# Epoch 220, Training Loss: 0.2228, Training Accuracy: 100.00%
# Validation Epoch 220/300:
# Validation Loss: 2.2311
# Validation Class Label Accuracy: 52.54%
# Validation Concept Accuracy: 90.28%
# Epoch 221, Training Loss: 0.2220, Training Accuracy: 100.00%
# Epoch 222, Training Loss: 0.2214, Training Accuracy: 100.00%
# Epoch 223, Training Loss: 0.2202, Training Accuracy: 100.00%
# Epoch 224, Training Loss: 0.2194, Training Accuracy: 100.00%
# Epoch 225, Training Loss: 0.2193, Training Accuracy: 100.00%
# Epoch 226, Training Loss: 0.2188, Training Accuracy: 99.98%
# Epoch 227, Training Loss: 0.2193, Training Accuracy: 100.00%
# Epoch 228, Training Loss: 0.2183, Training Accuracy: 100.00%
# Epoch 229, Training Loss: 0.2178, Training Accuracy: 99.98%
# Epoch 230, Training Loss: 0.2170, Training Accuracy: 100.00%
# Validation Epoch 230/300:
# Validation Loss: 2.2370
# Validation Class Label Accuracy: 52.88%
# Validation Concept Accuracy: 90.41%
# Epoch 231, Training Loss: 0.2164, Training Accuracy: 100.00%
# Epoch 232, Training Loss: 0.2173, Training Accuracy: 100.00%
# Epoch 233, Training Loss: 0.2158, Training Accuracy: 100.00%
# Epoch 234, Training Loss: 0.2161, Training Accuracy: 100.00%
# Epoch 235, Training Loss: 0.2163, Training Accuracy: 100.00%
# Epoch 236, Training Loss: 0.2155, Training Accuracy: 100.00%
# Epoch 237, Training Loss: 0.2147, Training Accuracy: 100.00%
# Epoch 238, Training Loss: 0.2136, Training Accuracy: 100.00%
# Epoch 239, Training Loss: 0.2119, Training Accuracy: 100.00%
# Epoch 240, Training Loss: 0.2126, Training Accuracy: 99.98%
# Validation Epoch 240/300:
# Validation Loss: 2.2401
# Validation Class Label Accuracy: 52.46%
# Validation Concept Accuracy: 90.42%
# Epoch 241, Training Loss: 0.2126, Training Accuracy: 100.00%
# Epoch 242, Training Loss: 0.2130, Training Accuracy: 100.00%
# Epoch 243, Training Loss: 0.2114, Training Accuracy: 99.98%
# Epoch 244, Training Loss: 0.2108, Training Accuracy: 100.00%
# Epoch 245, Training Loss: 0.2089, Training Accuracy: 100.00%
# Epoch 246, Training Loss: 0.2096, Training Accuracy: 100.00%
# Epoch 247, Training Loss: 0.2095, Training Accuracy: 100.00%
# Epoch 248, Training Loss: 0.2088, Training Accuracy: 100.00%
# Epoch 249, Training Loss: 0.2077, Training Accuracy: 99.98%
# Epoch 250, Training Loss: 0.2080, Training Accuracy: 99.98%
# Validation Epoch 250/300:
# Validation Loss: 2.2711
# Validation Class Label Accuracy: 51.71%
# Validation Concept Accuracy: 90.37%
# Epoch 251, Training Loss: 0.2070, Training Accuracy: 100.00%
# Epoch 252, Training Loss: 0.2061, Training Accuracy: 100.00%
# Epoch 253, Training Loss: 0.2062, Training Accuracy: 100.00%
# Epoch 254, Training Loss: 0.2057, Training Accuracy: 100.00%
# Epoch 255, Training Loss: 0.2044, Training Accuracy: 100.00%
# Epoch 256, Training Loss: 0.2053, Training Accuracy: 99.98%
# Epoch 257, Training Loss: 0.2064, Training Accuracy: 99.98%
# Epoch 258, Training Loss: 0.2052, Training Accuracy: 100.00%
# Epoch 259, Training Loss: 0.2047, Training Accuracy: 100.00%
# Epoch 260, Training Loss: 0.2045, Training Accuracy: 100.00%
# Validation Epoch 260/300:
# Validation Loss: 2.2429
# Validation Class Label Accuracy: 51.54%
# Validation Concept Accuracy: 90.50%
# Epoch 261, Training Loss: 0.2049, Training Accuracy: 100.00%
# Epoch 262, Training Loss: 0.2058, Training Accuracy: 100.00%
# Epoch 263, Training Loss: 0.2047, Training Accuracy: 99.98%
# Epoch 264, Training Loss: 0.2036, Training Accuracy: 100.00%
# Epoch 265, Training Loss: 0.2024, Training Accuracy: 100.00%
# Epoch 266, Training Loss: 0.2017, Training Accuracy: 100.00%
# Epoch 267, Training Loss: 0.2013, Training Accuracy: 100.00%
# Epoch 268, Training Loss: 0.2007, Training Accuracy: 100.00%
# Epoch 269, Training Loss: 0.2001, Training Accuracy: 100.00%
# Epoch 270, Training Loss: 0.1995, Training Accuracy: 100.00%
# Validation Epoch 270/300:
# Validation Loss: 2.2447
# Validation Class Label Accuracy: 52.63%
# Validation Concept Accuracy: 90.55%
# Epoch 271, Training Loss: 0.1985, Training Accuracy: 100.00%
# Epoch 272, Training Loss: 0.1977, Training Accuracy: 100.00%
# Epoch 273, Training Loss: 0.1974, Training Accuracy: 100.00%
# Epoch 274, Training Loss: 0.1979, Training Accuracy: 99.98%
# Epoch 275, Training Loss: 0.1980, Training Accuracy: 100.00%
# Epoch 276, Training Loss: 0.1970, Training Accuracy: 99.98%
# Epoch 277, Training Loss: 0.1967, Training Accuracy: 99.98%
# Epoch 278, Training Loss: 0.1984, Training Accuracy: 99.98%
# Epoch 279, Training Loss: 0.1981, Training Accuracy: 100.00%
# Epoch 280, Training Loss: 0.1972, Training Accuracy: 100.00%
# Validation Epoch 280/300:
# Validation Loss: 2.2824
# Validation Class Label Accuracy: 52.46%
# Validation Concept Accuracy: 90.51%
# Epoch 281, Training Loss: 0.1955, Training Accuracy: 100.00%
# Epoch 282, Training Loss: 0.1943, Training Accuracy: 100.00%
# Epoch 283, Training Loss: 0.1929, Training Accuracy: 100.00%
# Epoch 284, Training Loss: 0.1927, Training Accuracy: 99.98%
# Epoch 285, Training Loss: 0.1927, Training Accuracy: 100.00%
# Epoch 286, Training Loss: 0.1926, Training Accuracy: 99.94%
# Epoch 287, Training Loss: 0.1933, Training Accuracy: 100.00%
# Epoch 288, Training Loss: 0.1918, Training Accuracy: 100.00%
# Epoch 289, Training Loss: 0.1919, Training Accuracy: 100.00%
# Epoch 290, Training Loss: 0.1921, Training Accuracy: 99.98%
# Validation Epoch 290/300:
# Validation Loss: 2.2649
# Validation Class Label Accuracy: 52.13%
# Validation Concept Accuracy: 90.57%
# Epoch 291, Training Loss: 0.1916, Training Accuracy: 100.00%
# Epoch 292, Training Loss: 0.1900, Training Accuracy: 100.00%
# Epoch 293, Training Loss: 0.1915, Training Accuracy: 99.98%
# Epoch 294, Training Loss: 0.1919, Training Accuracy: 100.00%
# Epoch 295, Training Loss: 0.1908, Training Accuracy: 99.98%
# Epoch 296, Training Loss: 0.1892, Training Accuracy: 99.98%
# Epoch 297, Training Loss: 0.1898, Training Accuracy: 100.00%
# Epoch 298, Training Loss: 0.1894, Training Accuracy: 100.00%
# Epoch 299, Training Loss: 0.1889, Training Accuracy: 100.00%
# Epoch 300, Training Loss: 0.1881, Training Accuracy: 100.00%
# Validation Epoch 300/300:
# Validation Loss: 2.2340
# Validation Class Label Accuracy: 52.71%
# Validation Concept Accuracy: 90.58%
# CPU times: user 12min 33s, sys: 8min 18s, total: 20min 51s
# Wall time: 21min 19s

# %%
# Evaluate model
def evaluate_model(model, test_dataloader, device='cuda'):
    model.eval()  # Set to evaluation mode
    val_acc = 0.0
    concept_acc = 0.0
    val_total = 0
    concept_total = 0

    with torch.no_grad():
        for images, concepts, labels in test_dataloader:
            images = images.to(device)
            concepts = concepts.to(device)
            labels = labels.to(device)

            predicted_labels, predicted_concepts = model(images, return_concepts=True)
            _, predicted = torch.max(predicted_labels.data, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()
            concept_total += concepts.size(0) * concepts.size(1)
            preds = (predicted_concepts > 0.5).float()  # Need to threshold sigmoid outputs
            concept_acc += (preds == concepts).float().sum()

    val_acc = 100 * val_acc / val_total
    concept_acc = 100 * concept_acc / concept_total
    #print(f'Validation Loss: {running_loss/len(train_loader):.4f}')
    print(f'Test Class Label Accuracy: {val_acc:.2f}%')
    print(f'Test Concept Accuracy: {concept_acc:.2f}%')
    return val_acc, concept_acc


evaluate_model(model, test_loader)


best_state_dict = copy.deepcopy(model.state_dict())
torch.save(best_state_dict, 'cub_model.pth')
# Out:
# Test Class Label Accuracy: 52.71%
# Test Concept Accuracy: 90.66%

# %%
def check_data_ranges(dataloader, name=""):
    label_min = float('inf')
    label_max = float('-inf')
    concept_mins = None  # Changed from list to None
    concept_maxs = None

    for _, concepts, labels in dataloader:
        label_min = min(label_min, labels.min().item())
        label_max = max(label_max, labels.max().item())

        if concept_mins is None:  # First iteration
            concept_mins = concepts.min(dim=0)[0]
            concept_maxs = concepts.max(dim=0)[0]
        else:
            concept_mins = torch.minimum(concept_mins, concepts.min(dim=0)[0])
            concept_maxs = torch.maximum(concept_maxs, concepts.max(dim=0)[0])

    print(f"\n{name} Dataset Stats:")
    print(f"Label range: {label_min} to {label_max}")
    print(f"Number of unique concepts: {len(concept_mins)}")
    #print("Concept ranges:")
    #for i, (min_val, max_val) in enumerate(zip(concept_mins, concept_maxs)):
    #    print(f"Concept {i}: {min_val:.2f} to {max_val:.2f}")

# Check both datasets
check_data_ranges(train_loader, "Train")
check_data_ranges(val_loader, "Val")
check_data_ranges(test_loader, "Test")
# Out:
# Train Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Val Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312
#
# Test Dataset Stats:
# Label range: 0 to 199
# Number of unique concepts: 312

# %%
def check_image_stats(dataloader, name=""):
    first_batch = next(iter(dataloader))
    images, concepts, labels = first_batch

    print(f"\n{name} Dataset Image Stats:")
    print(f"Image tensor shape: {images.shape}")  # Should be [batch_size, channels, height, width]
    print(f"Image dtype: {images.dtype}")
    print(f"Value range: min={images.min():.3f}, max={images.max():.3f}")
    print(f"Mean: {images.mean():.3f}")
    print(f"Std: {images.std():.3f}")

    # Check for NaN/Inf
    print(f"Contains NaN: {torch.isnan(images).any()}")
    print(f"Contains Inf: {torch.isinf(images).any()}")

# Check both datasets
check_image_stats(train_loader, "Train")
check_image_stats(val_loader, "Val")
check_image_stats(test_loader, "Test")
# Out:
# Train Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.090
# Std: 1.051
# Contains NaN: False
# Contains Inf: False
#
# Val Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.114
# Std: 1.070
# Contains NaN: False
# Contains Inf: False
#
# Test Dataset Image Stats:
# Image tensor shape: torch.Size([512, 3, 224, 224])
# Image dtype: torch.float32
# Value range: min=-2.118, max=2.640
# Mean: 0.118
# Std: 1.048
# Contains NaN: False
# Contains Inf: False
